# %% [markdown]
# #AAI-520-NLP Final
# #Professor Andrew Van Benschoten
# ##Students: Hani Jandali, Kay M, Subhabrata Ganguli
# ###October 21st, 2024

# %% [markdown]
# #Libraries

# %% [markdown]
#  - All necessary libraries, tools, and utilities needed to approach the language model. Torch and related imports are for deep learning tasks, and utilities like csv, os, json for handling the actual data.

# %%
pip install rouge
# Out:
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.16.0)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
import itertools
import math
import json
import spacy
import nltk
from torch.jit import script, trace
from io import open
from torch import optim
from nltk.translate.bleu_score import sentence_bleu
from rouge import Rouge

# %% [markdown]
#  - Given the computational resources required of training a model, we will begin setup for GPU resource instead of CPU

# %%
USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %% [markdown]
#  - Next we mount our Google Drive to access the files. For my notebook the file structure in the Google Drive is the Drive -> Folder named "Movie_Corpus" -> All necessary files.

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
#  - For simplicity and cleaner code, I set a few paths from now that would be necessary in multiple functions.

# %%
#Google Drive paths for read in/saving
corpus_name = "Movie_Corpus"
corpus = os.path.join("/content/drive/My Drive/", corpus_name)
save_dir = os.path.join("/content/drive/My Drive/Movie_Corpus", "save")
datafile = os.path.join("/content/drive/My Drive/Movie_Corpus", "datafile.txt")

# %% [markdown]
#  - Reading in the first file, utterances.jsonl saved in the Movie_Corpus folder, to see the data we are working with. It is important to note, on Kaggle all files are loaded in as .txt files before we change them into dataframes. However, there were issues of having nested lists, contiguous token errors, dictionary break downs, and even an illegal action error that appears for which I could not account. From the official website, I loaded in a second version of the data as .json or .jsonl files to more easily work with data.

# %% [markdown]
# #Preprocessing

# %%
#Print first few lines of our utterance file
def printLines(file, n=5):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

printLines(os.path.join(corpus, "utterances.jsonl"))
# Out:
# b'{"id": "L1045", "conversation_id": "L1044", "text": "They do not!", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "not", "tag": "RB", "dep": "neg", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L1044", "timestamp": null, "vectors": []}\n'
# b'{"id": "L1044", "conversation_id": "L1044", "text": "They do to!", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "to", "tag": "TO", "dep": "dobj", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L985", "conversation_id": "L984", "text": "I hope so.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "hope", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "so", "tag": "RB", "dep": "advmod", "up": 1, "dn": []}, {"tok": ".", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L984", "timestamp": null, "vectors": []}\n'
# b'{"id": "L984", "conversation_id": "L984", "text": "She okay?", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "She", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "okay", "tag": "RB", "dep": "ROOT", "dn": [0, 2]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L925", "conversation_id": "L924", "text": "Let\'s go.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Let", "tag": "VB", "dep": "ROOT", "dn": [2, 3]}, {"tok": "\'s", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "go", "tag": "VB", "dep": "ccomp", "up": 0, "dn": [1]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L924", "timestamp": null, "vectors": []}\n'

# %% [markdown]
#  - We can note that the metadata is structured in a dictionary. The two classes of data we ideally want are the lines that form conversations. Below we will parse the lines in the utterances file to extract the necessary data.

# %%
#Splits each line and fill into empty dictionaries
def LinesAndConvos(fileName):
    #Dictionaries to store individual lines and conversations
    lines = {}
    conversations = {}
    #Open with iso-encoding instead of UUT-8
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            lineJson = json.loads(line)
            #Extract fields for line object
            lineObj = {}
            lineObj["lineID"] = lineJson["id"]
            lineObj["characterID"] = lineJson["speaker"]
            lineObj["text"] = lineJson["text"]
            lines[lineObj['lineID']] = lineObj
            #Extract fields for conversation object
            if lineJson["conversation_id"] not in conversations:
                convObj = {}
                convObj["conversationID"] = lineJson["conversation_id"]
                convObj["movieID"] = lineJson["meta"]["movie_id"]
                convObj["lines"] = [lineObj]
            else:
                #Add line to existing convo
                convObj = conversations[lineJson["conversation_id"]]
                convObj["lines"].insert(0, lineObj)
            conversations[convObj["conversationID"]] = convObj
    return lines, conversations

# %% [markdown]
#  - We then further process the information by converting the derived conversations into pairs of inputs and outputs (an input being a dialogue from a character in the corpus, and the output the response of another character to the input).

# %%
#Extracts pairs of sentences from conversations
def extractSentencePairs(conversations):
    #List to store question-answer pairs
    qa_pairs = []
    for conversation in conversations.values():
        #Iterate over all lines of convo
        for i in range(len(conversation["lines"]) - 1):
            #strip whitespace
            inputLine = conversation["lines"][i]["text"].strip()
            #Next line becomes target
            targetLine = conversation["lines"][i+1]["text"].strip()
            #Filter out samples without valid input/targets
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    #Now we can return extracted sentence pairs
    return qa_pairs

# %% [markdown]
#  - From this step, we can initialize empty dictionaries, read in our reformatted utterences file, and have our idealized dataset to further clean and refine for our model.

# %%
#Forgot to define above, path to newly created file
datafile = os.path.join(corpus, "formatted_movie_lines.txt")

delimiter = '\t'
#Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

#Initialize lines dict and conversations dict
lines = {}
conversations = {}

#Load lines and convos
print("\nProcessing corpus into lines and conversations...")
lines, conversations = LinesAndConvos(os.path.join(corpus, "utterances.jsonl"))

#Create and write a new csv file in utf-8 encoding
print("\nWriting newly formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(conversations):
        writer.writerow(pair)

#Ensure it worked, let's see
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Processing corpus into lines and conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b'They do to!\tThey do not!\n'
# b'She okay?\tI hope so.\n'
# b"Wow\tLet's go.\n"
# b'"I\'m kidding.  You know how sometimes you just become this ""persona""?  And you don\'t know how to quit?"\tNo\n'
# b"No\tOkay -- you're gonna need to learn how to lie.\n"

# %% [markdown]
#  - This is where most of the preprocessing takes place. The Vocabulary class was created to manage the vocabulary of our chatbot and handle mapping between words, indices, match frequencies of word use in our dialogue, and filter out some terms to increase training speed.This is where most of the preprocessing takes place. Now tokenization is not explicitly called due to it's computational and time requirements, but it is mimicked. Many of the functions within the class such as addSentence() and normalizeString() account for basic tokenization by splitting individual words, converting terms to lowercase, removing accents and non-alphabetical characters, and adding spaces around punctuation. Further down we also call on indexesFromSentence to convert a sentence into indices using our dictionary.

# %%
#Crucial tokens for vocabulary.
#Padds short sentences
PAD_token = 0
#SOS token is Start-of-sentence
SOS_token = 1
#EOS is end-of-sentence
EOS_token = 2

class Vocabulary:
    def __init__(self, name):
        #Name of vocabulary
        self.name = name
        #Flag to check if trimming has occured (not yet)
        self.trimmed = False
        #Dictionaries to map words to index and their respective frequencies
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        #Set at 3 to account for 3 Pad,SOS, and Eos
        self.num_words = 3

    #Sentence input split into individual words and add to vocab
    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    #Adds a word if it isn't already in the vocab list
    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    #Trims out words below predefined threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        #Trimming is done
        self.trimmed = True
        #Store words meeting min_count
        keep_words = []
        #Keep words that occur more than that amount
        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)))

        #Reinitialize dictionaries to keep those frequent words
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3
        #Add only frequent words back to vocab
        for word in keep_words:
            self.addWord(word)

# %%
#Turn unicode to ASCII
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')

# %%
# Updated normalizeString function with NLTK tokenization
def normalizeString(s):
    #First converting to lowercase and removing accents
    s = unicodeToAscii(s.lower().strip())
    #Separate out punctuation
    s = re.sub(r"([.!?])", r" \1", s)
    #Remove non-alphabet letters
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    #Replace spaces with single space
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# %%
#Max length of sentence considered
MAX_LENGTH = 10

# %%
#Read query/response pairs and return a voc object
def readVocab(datafile, corpus_name):
    print("Reading lines...")
    #Read and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    #Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    vocab = Vocabulary(corpus_name)
    return vocab, pairs

# %% [markdown]
#  - Now that most of the preprocessing is done, we simply need to filter the pairs based on a set max length. This helps with computational processing and in the end with chatbot coherence and efficiency for it's responses.

# %%
#Check if sentence pairs are under max length
def filterPair(p):
    #Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# %% [markdown]
#  - Based on that, we retain only those sentence pairs under our maximum length.

# %%
#Filter pairs using ``filterPair`` condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %% [markdown]
#  - We have a lot of moving parts operating at this point. So we will utilize LoadAndPrepare function to narrow things down.

# %%
#Using everything, return a populated voc object and pairs list
def loadAndPrepare(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    #Read and normalize the sentence pairs
    vocab, pairs = readVocab(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    #Filter pairs based on the length
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    #Counting words, building vocab
    print("Counting words...")
    for pair in pairs:
        #Add query sentence to vocab
        vocab.addSentence(pair[0])
        #Add response sentence to vocab
        vocab.addSentence(pair[1])
    print("Counted words:", vocab.num_words)
    return vocab, pairs

# %% [markdown]
#  - Lastly we need to save our vocabulary. We set a directory in our Google Drive for it,  we can validate the data loading and preparation are performed correctly, showing a few samples to visually confirm.

# %%
#Assemble voc and pairs
save_dir = os.path.join("data", "save")
vocab, pairs = loadAndPrepare(corpus, corpus_name, datafile, save_dir)
#Let's see a few
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64313 sentence pairs
# Counting words...
# Counted words: 18082
#
# pairs:
# ['they do to !', 'they do not !']
# ['she okay ?', 'i hope so .']
# ['wow', 'let s go .']
# ['what good stuff ?', 'the real you .']
# ['the real you .', 'like my fear of wearing pastels ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['have fun tonight ?', 'tons']

# %% [markdown]
#  - On the other end of the spectrum, we are going to further refine our data by trimming words that do not occur often. This way we can reduce the complexity of the model and it's response while also increaseing it's coherence in chat.

# %%
#minimum frequency for trimming
MIN_COUNT = 2

def trimRareWords(vocab, pairs, MIN_COUNT):
    #Trim words under threshold from vocabulary
    vocab.trim(MIN_COUNT)
    #Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        #Check input seqeunce.
        for word in input_sentence.split(' '):
            if word not in vocab.word2index:
                keep_input = False
                break
        #Check output sentence
        for word in output_sentence.split(' '):
            if word not in vocab.word2index:
                keep_output = False
                break
        #Only keep pairs without trimmed words in input/output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)
    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs
#Trim voc and pairs
pairs = trimRareWords(vocab, pairs, MIN_COUNT)

#Trim voc and pairs
pairs = trimRareWords(vocab, pairs, MIN_COUNT)
# Out:
# keep_words 11381 / 18079 = 0.6295
# Trimmed from 64313 pairs to 58494, 0.9095 of total
# Trimmed from 58494 pairs to 58494, 1.0000 of total

# %% [markdown]
#  - As seen above, we still maintain most of our vocabulary, so it is a solid optimization step with little downsides. We then move forward and convert the sentences we've kept into indices representing each word. The key factor here is including our End-Of-Sequence token at the end for our future input. This step is necessary overall to convert the data into a type for the model to process.

# %%
# Update function to convert sentence to indices
def indexesFromSentence(vocab, sentence):
    return [vocab.word2index[word] for word in sentence.split(' ')] + [EOS_token]

# %% [markdown]
#  - We then pad the sequences to ensure all data input into the model is of the same length. Without this step, the model would crash due to unexpected InputErrors.

# %%
def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

# %% [markdown]
#  - We also set up a binary matrix to create a binary mask for the padded sequences to help identify which instances were valid tokens (indicated with a 1) and which required padding (indicated with a 0). With this method we can ignore padded tokens during our loss calculations, which maintains the purity of our evaluation metrics.

# %%
def binaryMatrix(l, value=PAD_token):
    #Set empty dictionary
    m = []
    #Loop over each sequence and append for non-padded tokens
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# %% [markdown]
#  - We then have two functions to handle input and outputs. InputVar returns the tensor and lengths of the original sentences before padding. OutputVar prepares the target sentences for processing by converting them to padded tensors, initializing teh binarymask, and returning the maximum target length.

# %%
#Convert batch of input sentences
def inputVar(l, vocab):
    #Convert each sentence into list of indices
    indexes_batch = [indexesFromSentence(vocab, sentence) for sentence in l]
    #Create tensor containing og lengths of each sentence before padding
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    #pad sentences to equal lengths
    padList = zeroPadding(indexes_batch)
    #Convert to tensor in pytorch
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# %%
def outputVar(l, vocab):
    #Convert batch of target sentences to indices
    indexes_batch = [indexesFromSentence(vocab, sentence) for sentence in l]
    #Find length of longest sentence in batch as reference padding
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    #Pad all sentences to that length
    padList = zeroPadding(indexes_batch)
    #Create binary mask where valid and padded tokens are marked
    mask = binaryMatrix(padList)
    #Convert binary mask into tensor
    mask = torch.BoolTensor(mask)
    #Convert padded sentences into tensor
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# %% [markdown]
#  - Lastly we convert the batches of input/output sentence pairs to feed into our model.

# %%
# Updated batch2TrainData function to use NLTK tokenization
def batch2TrainData(vocab, pair_batch):
    # Sort batch of sentence pairs by length
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    # Separate input/output into two separate lists
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, vocab)
    output, mask, max_target_len = outputVar(output_batch, vocab)
    return inp, lengths, output, mask, max_target_len

# %%
#Test out and see
small_batch_size = 5
batches = batch2TrainData(vocab, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[  11,   24,   51,  818, 2837],
#         [1025,  122,   65,   14,   10],
#         [9820,  256,  859,    2,    2],
#         [ 214,  214,   11,    0,    0],
#         [  63,   36,   48,    0,    0],
#         [ 643, 1066,    2,    0,    0],
#         [ 609,   14,    0,    0,    0],
#         [  10,    2,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([9, 8, 6, 3, 3])
# target_variable: tensor([[ 228,    3,    3,  179,   34],
#         [  10,   65,  552,  110,  398],
#         [   2,  605,  988,   24,   24],
#         [   0,  663, 2459,   10,   14],
#         [   0,  100, 1092,    2,    2],
#         [   0, 2231,   14,    0,    0],
#         [   0,   14,    2,    0,    0],
#         [   0,    2,    0,    0,    0]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [False,  True,  True,  True,  True],
#         [False,  True,  True,  True,  True],
#         [False,  True,  True, False, False],
#         [False,  True,  True, False, False],
#         [False,  True, False, False, False]])
# max_target_len: 8

# %% [markdown]
#  - It is important to note that although we did not use explicit tokenization methods from NLTK/SpaCy, we still result with appropriate tensors.

# %% [markdown]
# #Modeling

# %% [markdown]
#  - The model used here was a Sequence-to-Sequence model with specialized Luong attention mechanisms and bidirectional gated-recurrent-units (for input, unidirectional in output). It's similar to RNN models (hence the function name) and is composed of two essential portions: encoder and decoder. It operates by feeding an input sentence into the encoder which transforms it into a hidden representation of itself for which the decoder generates an output (our chatbot response) from decoding it.
#
#  - The encoder itself is, as mentioned above, a bidirectional GRU, used due to the effectiveness of capturing contextual information and long-range dependencies from both forward and backwards processing. The resulting concatenated hidden state is passed to the decoder for text generation.

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        '''Clarification in initializing GRU - the input_size and hidden_size parameters are both set to 'hidden_size'
        #because our input size is a word embedding with number of features == hidden_size'''
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        #Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        #Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        #Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        #Unpacking padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        #Sum together the bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        #Return output and final hidden state
        return outputs, hidden

# %% [markdown]
#  - The real gem of this implementation is the Luong attention mechanism. It helps with potentially long inputs from the user which was a proven issue in previous attempts of this final project, and also helps against vanishing gradients to aid with context. There is also an added flexibility in training by means of the scoring options which we will cover below (dot, general, concatenation)

# %%
#Luong attention layer from paper (need to add above)
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        #Of the 3 variants of attention mechanism to use between dot, general, and concat
        #We choose concat
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            #We also apply linear transformation to align dimensions of hidden state and encoder outputs for attention calc
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    #Attention score calculation (dot product) of hidden state of decoder and encoder output
    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    #Same thing but energy tensor created from applying linear transformation to encoder output
    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    #Same thing as dot score too, but concatenates decoders hidden state and encoder output before passing through linear transformation
    #And then non-linear activation function (favorite=tanh)
    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        #Calculate the attention weights (energies) based on the given method chosen, all 3 for exploration
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)
        #Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()
        #Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()
        #Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout
        #Embedding layer will map word indices to dense vectors
        self.embedding = embedding
        #Dropout for stabilization via regularization/overfitting
        self.embedding_dropout = nn.Dropout(dropout)
        #Unidirectional GRU
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        #Linear layer to convert final hidden state into output space for each word
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        #Convert finall hidden state to output
        self.out = nn.Linear(hidden_size, output_size)
        #calculate attention score
        self.attn = Attn(attn_model, hidden_size)

    #Forward pass for decoder to generate
    def forward(self, input_step, last_hidden, encoder_outputs):
        #Important Note: run this one step (word) at a time
        #Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        #Forward through GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        #Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        #Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        #Concatenate weighted context vector and GRU output using Luong equation 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        #Predict next word using Luong equation 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # eturn output and final hidden state
        return output, hidden

# %% [markdown]
#  - The Negative Log-Likelihood calculation of loss for the model is calculated through the below function. It helps in calculation with various sizes of input and output sequences.

# %%
#Masked negative log-likelihood
def maskNLLLoss(inp, target, mask):
    #Count total number of non-padded elements
    nTotal = mask.sum()
    #Get predicted values from input corresponding to correct target values
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    #Average loss for current batch
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):
    #Reset gradients to zero
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    #Set everything to GPU
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)

    #Lengths for RNN packing should always be on the CPU because of tensorflow library
    lengths = lengths.to("cpu")

    #Initialize variables and dictionary to store
    loss = 0
    print_losses = []
    n_totals = 0

    #Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    #Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    #Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    #Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    #Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            #Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            #Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            #No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            #Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    #Perform backpropagation
    loss.backward()

    #Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)
    #Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()
    return sum(print_losses) / n_totals

# %%
def save_model(encoder, decoder, model_name):
    model_path = f"/content/drive/My Drive/Movie_Corpus/{model_name}.pth"
    torch.save({
        'encoder_state_dict': encoder.state_dict(),
        'decoder_state_dict': decoder.state_dict(),
    }, model_path)
    print(f"Model saved to {model_path}")

# %%
def trainIters(model_name, vocab, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding,
               encoder_n_layers, decoder_n_layers, n_iteration, batch_size, print_every, clip):
    #Load batches for each iteration
    training_batches = [batch2TrainData(vocab, [random.choice(pairs) for _ in range(batch_size)])
                        for _ in range(n_iteration)]

    #Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0

    #Loop through trianing
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        #Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch
        #Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        #Progress:
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print(f"Iteration: {iteration}; Percent complete: {iteration / n_iteration * 100:.1f}%; Average loss: {print_loss_avg:.4f}")
            print_loss = 0
    #Save the model out of loop so only final iteration of training is kept
    save_model(encoder, decoder, model_name)

# %% [markdown]
#  - Greedy Search Decoding is used to generate the sequence of output tokens from our model. It was chosen for computational efficiency as with many decisions throughout this project, and simply selects the highest probability token at each step of decoding as the response.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        #Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        #Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        #Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        #Initialize tensors to append decoded words
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            #Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            #Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            #Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            #Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        #Return collections of word tokens and scores
        return all_tokens, all_scores

# %%
def evaluate(encoder, decoder, searcher, vocab, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    #words -> indexes
    indexes_batch = [indexesFromSentence(vocab, sentence)]
    #Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    #Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    #Set to GPU and tensors to CPU
    input_batch = input_batch.to(device)
    lengths = lengths.to("cpu")
    #Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    #indexes to words
    decoded_words = [vocab.index2word[token.item()] for token in tokens]
    return decoded_words

# %%
def evaluateInput(encoder, decoder, searcher, vocab):
    input_sentence = ''
    while True:
        try:
            #Get input sentence
            input_sentence = input('> ')
            #Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            #Normalize sentence
            input_sentence = normalizeString(input_sentence)
            #Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, vocab, input_sentence)
            # ormat and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))
        except KeyError:
            print("Error: Encountered unknown word.")

# %% [markdown]
#  - Our model configurations are listed below. One of the incredible features to a Luong attention mechanism is accounted for here via attention score calculations. There are 3 types: dot, general, and concat. In testing, dot has proven to be the most effective considering the simplicity of our model. The operate as follows:
#
#   - Dot Product: Calculates the attention score as the dot product between the decoder's hidden state and the encoder's output. Computationally inexpensive, easy to use.
#
#   - General: Similar to dot product, but applies a learnable linear transformation to the encoder's output before taking the dot product. More flexible and complex.
#
#   - Concat: It concatenates the decoder hidden state with the encoder output and passes them through a feed-forward network with a non-linear activation (tanh or sigmoid). It is the most complex and intensive.

# %%
#Configure models
model_name = 'AAI_520_V3'
attn_model = 'dot'
#``attn_model = 'general'``
#``attn_model = 'concat'``
hidden_size = 1000
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.2
batch_size = 128
n_iteration = 10000
print_every = 1
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0

# %% [markdown]
#  - After setting our model's configuration, we initialize everything and build our model.

# %%
print('Building encoder and decoder ...')
#Initialize word embeddings
embedding = nn.Embedding(vocab.num_words, hidden_size)

#Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, vocab.num_words, decoder_n_layers, dropout)

#Move models to GPU
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models initialized from scratch and ready to go!')
# Out:
# Building encoder and decoder ...
# Models initialized from scratch and ready to go!

# %% [markdown]
#  - Lastly, we start training our model below on GPU, in this case A100 runtime in Google Colab. Training can range between 10 minutes to 10 hours depending on configuration.

# %%
#Initialize word embeddings
embedding = nn.Embedding(vocab.num_words, hidden_size)

#Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, vocab.num_words, decoder_n_layers, dropout)

#Move models to GPU
encoder = encoder.to(device)
decoder = decoder.to(device)

#Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)

#Configure Cude to call for optimized state
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

#Start training
print("Starting Training!")
trainIters(model_name, vocab, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, n_iteration, batch_size,
           print_every, clip)
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration: 5002; Percent complete: 50.0%; Average loss: 0.5898
# Iteration: 5003; Percent complete: 50.0%; Average loss: 0.7557
# Iteration: 5004; Percent complete: 50.0%; Average loss: 0.7527
# Iteration: 5005; Percent complete: 50.0%; Average loss: 0.8282
# Iteration: 5006; Percent complete: 50.1%; Average loss: 0.6882
# Iteration: 5007; Percent complete: 50.1%; Average loss: 0.8351
# Iteration: 5008; Percent complete: 50.1%; Average loss: 0.6976
# Iteration: 5009; Percent complete: 50.1%; Average loss: 0.7076
# Iteration: 5010; Percent complete: 50.1%; Average loss: 0.7357
# Iteration: 5011; Percent complete: 50.1%; Average loss: 0.7671
# Iteration: 5012; Percent complete: 50.1%; Average loss: 0.6660
# Iteration: 5013; Percent complete: 50.1%; Average loss: 0.7419
# Iteration: 5014; Percent complete: 50.1%; Average loss: 0.6234
# Iteration: 5015; Percent complete: 50.1%; Average loss: 0.7395
# Iteration: 5016; Percent complete: 50.2%; Average loss: 0.8214
# Iteration: 5017; Percent complete: 50.2%; Average loss: 0.8209
# Iteration: 5018; Percent complete: 50.2%; Average loss: 0.7630
# Iteration: 5019; Percent complete: 50.2%; Average loss: 0.7218
# Iteration: 5020; Percent complete: 50.2%; Average loss: 0.7114
# Iteration: 5021; Percent complete: 50.2%; Average loss: 0.7105
# Iteration: 5022; Percent complete: 50.2%; Average loss: 0.7010
# Iteration: 5023; Percent complete: 50.2%; Average loss: 0.6701
# Iteration: 5024; Percent complete: 50.2%; Average loss: 0.8626
# Iteration: 5025; Percent complete: 50.2%; Average loss: 0.7826
# Iteration: 5026; Percent complete: 50.3%; Average loss: 0.7177
# Iteration: 5027; Percent complete: 50.3%; Average loss: 0.8551
# Iteration: 5028; Percent complete: 50.3%; Average loss: 0.7826
# Iteration: 5029; Percent complete: 50.3%; Average loss: 0.6912
# Iteration: 5030; Percent complete: 50.3%; Average loss: 0.7900
# Iteration: 5031; Percent complete: 50.3%; Average loss: 0.7927
# Iteration: 5032; Percent complete: 50.3%; Average loss: 0.7201
# Iteration: 5033; Percent complete: 50.3%; Average loss: 0.7266
# Iteration: 5034; Percent complete: 50.3%; Average loss: 0.6786
# Iteration: 5035; Percent complete: 50.3%; Average loss: 0.8103
# Iteration: 5036; Percent complete: 50.4%; Average loss: 0.7771
# Iteration: 5037; Percent complete: 50.4%; Average loss: 0.7410
# Iteration: 5038; Percent complete: 50.4%; Average loss: 0.6953
# Iteration: 5039; Percent complete: 50.4%; Average loss: 0.7705
# Iteration: 5040; Percent complete: 50.4%; Average loss: 0.6928
# Iteration: 5041; Percent complete: 50.4%; Average loss: 0.7868
# Iteration: 5042; Percent complete: 50.4%; Average loss: 0.7715
# Iteration: 5043; Percent complete: 50.4%; Average loss: 0.7166
# Iteration: 5044; Percent complete: 50.4%; Average loss: 0.8520
# Iteration: 5045; Percent complete: 50.4%; Average loss: 0.6928
# Iteration: 5046; Percent complete: 50.5%; Average loss: 0.7678
# Iteration: 5047; Percent complete: 50.5%; Average loss: 0.7564
# Iteration: 5048; Percent complete: 50.5%; Average loss: 0.7968
# Iteration: 5049; Percent complete: 50.5%; Average loss: 0.7127
# Iteration: 5050; Percent complete: 50.5%; Average loss: 0.7556
# Iteration: 5051; Percent complete: 50.5%; Average loss: 0.6334
# Iteration: 5052; Percent complete: 50.5%; Average loss: 0.8306
# Iteration: 5053; Percent complete: 50.5%; Average loss: 0.7333
# Iteration: 5054; Percent complete: 50.5%; Average loss: 0.7473
# Iteration: 5055; Percent complete: 50.5%; Average loss: 0.6745
# Iteration: 5056; Percent complete: 50.6%; Average loss: 0.6811
# Iteration: 5057; Percent complete: 50.6%; Average loss: 0.7691
# Iteration: 5058; Percent complete: 50.6%; Average loss: 0.7547
# Iteration: 5059; Percent complete: 50.6%; Average loss: 0.8297
# Iteration: 5060; Percent complete: 50.6%; Average loss: 0.7174
# Iteration: 5061; Percent complete: 50.6%; Average loss: 0.6472
# Iteration: 5062; Percent complete: 50.6%; Average loss: 0.6909
# Iteration: 5063; Percent complete: 50.6%; Average loss: 0.7084
# Iteration: 5064; Percent complete: 50.6%; Average loss: 0.7647
# Iteration: 5065; Percent complete: 50.6%; Average loss: 0.7641
# Iteration: 5066; Percent complete: 50.7%; Average loss: 0.8226
# Iteration: 5067; Percent complete: 50.7%; Average loss: 0.6846
# Iteration: 5068; Percent complete: 50.7%; Average loss: 0.8250
# Iteration: 5069; Percent complete: 50.7%; Average loss: 0.6781
# Iteration: 5070; Percent complete: 50.7%; Average loss: 0.6241
# Iteration: 5071; Percent complete: 50.7%; Average loss: 0.8308
# Iteration: 5072; Percent complete: 50.7%; Average loss: 0.7767
# Iteration: 5073; Percent complete: 50.7%; Average loss: 0.7723
# Iteration: 5074; Percent complete: 50.7%; Average loss: 0.8045
# Iteration: 5075; Percent complete: 50.7%; Average loss: 0.7826
# Iteration: 5076; Percent complete: 50.8%; Average loss: 0.7207
# Iteration: 5077; Percent complete: 50.8%; Average loss: 0.7910
# Iteration: 5078; Percent complete: 50.8%; Average loss: 0.6959
# Iteration: 5079; Percent complete: 50.8%; Average loss: 0.6850
# Iteration: 5080; Percent complete: 50.8%; Average loss: 0.7442
# Iteration: 5081; Percent complete: 50.8%; Average loss: 0.7573
# Iteration: 5082; Percent complete: 50.8%; Average loss: 0.7469
# Iteration: 5083; Percent complete: 50.8%; Average loss: 0.8609
# Iteration: 5084; Percent complete: 50.8%; Average loss: 0.8996
# Iteration: 5085; Percent complete: 50.8%; Average loss: 0.7682
# Iteration: 5086; Percent complete: 50.9%; Average loss: 0.6731
# Iteration: 5087; Percent complete: 50.9%; Average loss: 0.7596
# Iteration: 5088; Percent complete: 50.9%; Average loss: 0.6488
# Iteration: 5089; Percent complete: 50.9%; Average loss: 0.7195
# Iteration: 5090; Percent complete: 50.9%; Average loss: 0.6896
# Iteration: 5091; Percent complete: 50.9%; Average loss: 0.7070
# Iteration: 5092; Percent complete: 50.9%; Average loss: 0.6661
# Iteration: 5093; Percent complete: 50.9%; Average loss: 0.7250
# Iteration: 5094; Percent complete: 50.9%; Average loss: 0.7429
# Iteration: 5095; Percent complete: 50.9%; Average loss: 0.6632
# Iteration: 5096; Percent complete: 51.0%; Average loss: 0.6968
# Iteration: 5097; Percent complete: 51.0%; Average loss: 0.6713
# Iteration: 5098; Percent complete: 51.0%; Average loss: 0.8243
# Iteration: 5099; Percent complete: 51.0%; Average loss: 0.7249
# Iteration: 5100; Percent complete: 51.0%; Average loss: 0.7180
# Iteration: 5101; Percent complete: 51.0%; Average loss: 0.7346
# Iteration: 5102; Percent complete: 51.0%; Average loss: 0.7244
# Iteration: 5103; Percent complete: 51.0%; Average loss: 0.8370
# Iteration: 5104; Percent complete: 51.0%; Average loss: 0.6781
# Iteration: 5105; Percent complete: 51.0%; Average loss: 0.6486
# Iteration: 5106; Percent complete: 51.1%; Average loss: 0.7042
# Iteration: 5107; Percent complete: 51.1%; Average loss: 0.7506
# Iteration: 5108; Percent complete: 51.1%; Average loss: 0.7618
# Iteration: 5109; Percent complete: 51.1%; Average loss: 0.7395
# Iteration: 5110; Percent complete: 51.1%; Average loss: 0.7772
# Iteration: 5111; Percent complete: 51.1%; Average loss: 0.7169
# Iteration: 5112; Percent complete: 51.1%; Average loss: 0.6724
# Iteration: 5113; Percent complete: 51.1%; Average loss: 0.7347
# Iteration: 5114; Percent complete: 51.1%; Average loss: 0.7741
# Iteration: 5115; Percent complete: 51.1%; Average loss: 0.7800
# Iteration: 5116; Percent complete: 51.2%; Average loss: 0.7288
# Iteration: 5117; Percent complete: 51.2%; Average loss: 0.8043
# Iteration: 5118; Percent complete: 51.2%; Average loss: 0.7222
# Iteration: 5119; Percent complete: 51.2%; Average loss: 0.7632
# Iteration: 5120; Percent complete: 51.2%; Average loss: 0.6292
# Iteration: 5121; Percent complete: 51.2%; Average loss: 0.6918
# Iteration: 5122; Percent complete: 51.2%; Average loss: 0.7162
# Iteration: 5123; Percent complete: 51.2%; Average loss: 0.7125
# Iteration: 5124; Percent complete: 51.2%; Average loss: 0.7761
# Iteration: 5125; Percent complete: 51.2%; Average loss: 0.7359
# Iteration: 5126; Percent complete: 51.3%; Average loss: 0.6782
# Iteration: 5127; Percent complete: 51.3%; Average loss: 0.6113
# Iteration: 5128; Percent complete: 51.3%; Average loss: 0.7450
# Iteration: 5129; Percent complete: 51.3%; Average loss: 0.6841
# Iteration: 5130; Percent complete: 51.3%; Average loss: 0.7142
# Iteration: 5131; Percent complete: 51.3%; Average loss: 0.6878
# Iteration: 5132; Percent complete: 51.3%; Average loss: 0.7125
# Iteration: 5133; Percent complete: 51.3%; Average loss: 0.7653
# Iteration: 5134; Percent complete: 51.3%; Average loss: 0.6940
# Iteration: 5135; Percent complete: 51.3%; Average loss: 0.7368
# Iteration: 5136; Percent complete: 51.4%; Average loss: 0.7809
# Iteration: 5137; Percent complete: 51.4%; Average loss: 0.6029
# Iteration: 5138; Percent complete: 51.4%; Average loss: 0.6834
# Iteration: 5139; Percent complete: 51.4%; Average loss: 0.7287
# Iteration: 5140; Percent complete: 51.4%; Average loss: 0.7235
# Iteration: 5141; Percent complete: 51.4%; Average loss: 0.7356
# Iteration: 5142; Percent complete: 51.4%; Average loss: 0.6774
# Iteration: 5143; Percent complete: 51.4%; Average loss: 0.7255
# Iteration: 5144; Percent complete: 51.4%; Average loss: 0.7735
# Iteration: 5145; Percent complete: 51.4%; Average loss: 0.6871
# Iteration: 5146; Percent complete: 51.5%; Average loss: 0.7275
# Iteration: 5147; Percent complete: 51.5%; Average loss: 0.7270
# Iteration: 5148; Percent complete: 51.5%; Average loss: 0.7645
# Iteration: 5149; Percent complete: 51.5%; Average loss: 0.7647
# Iteration: 5150; Percent complete: 51.5%; Average loss: 0.7031
# Iteration: 5151; Percent complete: 51.5%; Average loss: 0.6729
# Iteration: 5152; Percent complete: 51.5%; Average loss: 0.8153
# Iteration: 5153; Percent complete: 51.5%; Average loss: 0.6774
# Iteration: 5154; Percent complete: 51.5%; Average loss: 0.7543
# Iteration: 5155; Percent complete: 51.5%; Average loss: 0.7328
# Iteration: 5156; Percent complete: 51.6%; Average loss: 0.6496
# Iteration: 5157; Percent complete: 51.6%; Average loss: 0.6553
# Iteration: 5158; Percent complete: 51.6%; Average loss: 0.7829
# Iteration: 5159; Percent complete: 51.6%; Average loss: 0.6315
# Iteration: 5160; Percent complete: 51.6%; Average loss: 0.7998
# Iteration: 5161; Percent complete: 51.6%; Average loss: 0.7322
# Iteration: 5162; Percent complete: 51.6%; Average loss: 0.6371
# Iteration: 5163; Percent complete: 51.6%; Average loss: 0.7774
# Iteration: 5164; Percent complete: 51.6%; Average loss: 0.8053
# Iteration: 5165; Percent complete: 51.6%; Average loss: 0.6745
# Iteration: 5166; Percent complete: 51.7%; Average loss: 0.6471
# Iteration: 5167; Percent complete: 51.7%; Average loss: 0.7373
# Iteration: 5168; Percent complete: 51.7%; Average loss: 0.7420
# Iteration: 5169; Percent complete: 51.7%; Average loss: 0.6165
# Iteration: 5170; Percent complete: 51.7%; Average loss: 0.8063
# Iteration: 5171; Percent complete: 51.7%; Average loss: 0.6890
# Iteration: 5172; Percent complete: 51.7%; Average loss: 0.6025
# Iteration: 5173; Percent complete: 51.7%; Average loss: 0.7204
# Iteration: 5174; Percent complete: 51.7%; Average loss: 0.5906
# Iteration: 5175; Percent complete: 51.7%; Average loss: 0.6309
# Iteration: 5176; Percent complete: 51.8%; Average loss: 0.6959
# Iteration: 5177; Percent complete: 51.8%; Average loss: 0.7036
# Iteration: 5178; Percent complete: 51.8%; Average loss: 0.7360
# Iteration: 5179; Percent complete: 51.8%; Average loss: 0.7100
# Iteration: 5180; Percent complete: 51.8%; Average loss: 0.6941
# Iteration: 5181; Percent complete: 51.8%; Average loss: 0.7622
# Iteration: 5182; Percent complete: 51.8%; Average loss: 0.6660
# Iteration: 5183; Percent complete: 51.8%; Average loss: 0.6784
# Iteration: 5184; Percent complete: 51.8%; Average loss: 0.6838
# Iteration: 5185; Percent complete: 51.8%; Average loss: 0.7346
# Iteration: 5186; Percent complete: 51.9%; Average loss: 0.7785
# Iteration: 5187; Percent complete: 51.9%; Average loss: 0.5937
# Iteration: 5188; Percent complete: 51.9%; Average loss: 0.6537
# Iteration: 5189; Percent complete: 51.9%; Average loss: 0.7187
# Iteration: 5190; Percent complete: 51.9%; Average loss: 0.6474
# Iteration: 5191; Percent complete: 51.9%; Average loss: 0.6688
# Iteration: 5192; Percent complete: 51.9%; Average loss: 0.8152
# Iteration: 5193; Percent complete: 51.9%; Average loss: 0.6746
# Iteration: 5194; Percent complete: 51.9%; Average loss: 0.7083
# Iteration: 5195; Percent complete: 51.9%; Average loss: 0.7204
# Iteration: 5196; Percent complete: 52.0%; Average loss: 0.6821
# Iteration: 5197; Percent complete: 52.0%; Average loss: 0.7022
# Iteration: 5198; Percent complete: 52.0%; Average loss: 0.7392
# Iteration: 5199; Percent complete: 52.0%; Average loss: 0.6721
# Iteration: 5200; Percent complete: 52.0%; Average loss: 0.7343
# Iteration: 5201; Percent complete: 52.0%; Average loss: 0.6751
# Iteration: 5202; Percent complete: 52.0%; Average loss: 0.7058
# Iteration: 5203; Percent complete: 52.0%; Average loss: 0.7835
# Iteration: 5204; Percent complete: 52.0%; Average loss: 0.8085
# Iteration: 5205; Percent complete: 52.0%; Average loss: 0.7383
# Iteration: 5206; Percent complete: 52.1%; Average loss: 0.6479
# Iteration: 5207; Percent complete: 52.1%; Average loss: 0.6941
# Iteration: 5208; Percent complete: 52.1%; Average loss: 0.7098
# Iteration: 5209; Percent complete: 52.1%; Average loss: 0.6375
# Iteration: 5210; Percent complete: 52.1%; Average loss: 0.6873
# Iteration: 5211; Percent complete: 52.1%; Average loss: 0.6692
# Iteration: 5212; Percent complete: 52.1%; Average loss: 0.6531
# Iteration: 5213; Percent complete: 52.1%; Average loss: 0.6999
# Iteration: 5214; Percent complete: 52.1%; Average loss: 0.6782
# Iteration: 5215; Percent complete: 52.1%; Average loss: 0.7292
# Iteration: 5216; Percent complete: 52.2%; Average loss: 0.6089
# Iteration: 5217; Percent complete: 52.2%; Average loss: 0.6922
# Iteration: 5218; Percent complete: 52.2%; Average loss: 0.8462
# Iteration: 5219; Percent complete: 52.2%; Average loss: 0.6927
# Iteration: 5220; Percent complete: 52.2%; Average loss: 0.7584
# Iteration: 5221; Percent complete: 52.2%; Average loss: 0.7619
# Iteration: 5222; Percent complete: 52.2%; Average loss: 0.5946
# Iteration: 5223; Percent complete: 52.2%; Average loss: 0.6721
# Iteration: 5224; Percent complete: 52.2%; Average loss: 0.6570
# Iteration: 5225; Percent complete: 52.2%; Average loss: 0.6338
# Iteration: 5226; Percent complete: 52.3%; Average loss: 0.5756
# Iteration: 5227; Percent complete: 52.3%; Average loss: 0.6861
# Iteration: 5228; Percent complete: 52.3%; Average loss: 0.6967
# Iteration: 5229; Percent complete: 52.3%; Average loss: 0.6277
# Iteration: 5230; Percent complete: 52.3%; Average loss: 0.6699
# Iteration: 5231; Percent complete: 52.3%; Average loss: 0.7400
# Iteration: 5232; Percent complete: 52.3%; Average loss: 0.6723
# Iteration: 5233; Percent complete: 52.3%; Average loss: 0.6956
# Iteration: 5234; Percent complete: 52.3%; Average loss: 0.7323
# Iteration: 5235; Percent complete: 52.3%; Average loss: 0.6616
# Iteration: 5236; Percent complete: 52.4%; Average loss: 0.7059
# Iteration: 5237; Percent complete: 52.4%; Average loss: 0.6585
# Iteration: 5238; Percent complete: 52.4%; Average loss: 0.8854
# Iteration: 5239; Percent complete: 52.4%; Average loss: 0.7743
# Iteration: 5240; Percent complete: 52.4%; Average loss: 0.6848
# Iteration: 5241; Percent complete: 52.4%; Average loss: 0.5932
# Iteration: 5242; Percent complete: 52.4%; Average loss: 0.5408
# Iteration: 5243; Percent complete: 52.4%; Average loss: 0.6925
# Iteration: 5244; Percent complete: 52.4%; Average loss: 0.6378
# Iteration: 5245; Percent complete: 52.4%; Average loss: 0.7051
# Iteration: 5246; Percent complete: 52.5%; Average loss: 0.6604
# Iteration: 5247; Percent complete: 52.5%; Average loss: 0.6394
# Iteration: 5248; Percent complete: 52.5%; Average loss: 0.6032
# Iteration: 5249; Percent complete: 52.5%; Average loss: 0.6997
# Iteration: 5250; Percent complete: 52.5%; Average loss: 0.6831
# Iteration: 5251; Percent complete: 52.5%; Average loss: 0.6845
# Iteration: 5252; Percent complete: 52.5%; Average loss: 0.7994
# Iteration: 5253; Percent complete: 52.5%; Average loss: 0.6093
# Iteration: 5254; Percent complete: 52.5%; Average loss: 0.7292
# Iteration: 5255; Percent complete: 52.5%; Average loss: 0.7153
# Iteration: 5256; Percent complete: 52.6%; Average loss: 0.7028
# Iteration: 5257; Percent complete: 52.6%; Average loss: 0.6901
# Iteration: 5258; Percent complete: 52.6%; Average loss: 0.6720
# Iteration: 5259; Percent complete: 52.6%; Average loss: 0.6868
# Iteration: 5260; Percent complete: 52.6%; Average loss: 0.5533
# Iteration: 5261; Percent complete: 52.6%; Average loss: 0.7546
# Iteration: 5262; Percent complete: 52.6%; Average loss: 0.6145
# Iteration: 5263; Percent complete: 52.6%; Average loss: 0.6005
# Iteration: 5264; Percent complete: 52.6%; Average loss: 0.5691
# Iteration: 5265; Percent complete: 52.6%; Average loss: 0.6722
# Iteration: 5266; Percent complete: 52.7%; Average loss: 0.6528
# Iteration: 5267; Percent complete: 52.7%; Average loss: 0.7113
# Iteration: 5268; Percent complete: 52.7%; Average loss: 0.6554
# Iteration: 5269; Percent complete: 52.7%; Average loss: 0.5550
# Iteration: 5270; Percent complete: 52.7%; Average loss: 0.6733
# Iteration: 5271; Percent complete: 52.7%; Average loss: 0.5835
# Iteration: 5272; Percent complete: 52.7%; Average loss: 0.6865
# Iteration: 5273; Percent complete: 52.7%; Average loss: 0.6724
# Iteration: 5274; Percent complete: 52.7%; Average loss: 0.6968
# Iteration: 5275; Percent complete: 52.8%; Average loss: 0.8116
# Iteration: 5276; Percent complete: 52.8%; Average loss: 0.6345
# Iteration: 5277; Percent complete: 52.8%; Average loss: 0.5901
# Iteration: 5278; Percent complete: 52.8%; Average loss: 0.7128
# Iteration: 5279; Percent complete: 52.8%; Average loss: 0.6870
# Iteration: 5280; Percent complete: 52.8%; Average loss: 0.6575
# Iteration: 5281; Percent complete: 52.8%; Average loss: 0.5939
# Iteration: 5282; Percent complete: 52.8%; Average loss: 0.7346
# Iteration: 5283; Percent complete: 52.8%; Average loss: 0.6007
# Iteration: 5284; Percent complete: 52.8%; Average loss: 0.6810
# Iteration: 5285; Percent complete: 52.8%; Average loss: 0.6857
# Iteration: 5286; Percent complete: 52.9%; Average loss: 0.5925
# Iteration: 5287; Percent complete: 52.9%; Average loss: 0.8386
# Iteration: 5288; Percent complete: 52.9%; Average loss: 0.6414
# Iteration: 5289; Percent complete: 52.9%; Average loss: 0.5893
# Iteration: 5290; Percent complete: 52.9%; Average loss: 0.6533
# Iteration: 5291; Percent complete: 52.9%; Average loss: 0.6802
# Iteration: 5292; Percent complete: 52.9%; Average loss: 0.6322
# Iteration: 5293; Percent complete: 52.9%; Average loss: 0.7110
# Iteration: 5294; Percent complete: 52.9%; Average loss: 0.5705
# Iteration: 5295; Percent complete: 52.9%; Average loss: 0.7567
# Iteration: 5296; Percent complete: 53.0%; Average loss: 0.7165
# Iteration: 5297; Percent complete: 53.0%; Average loss: 0.5948
# Iteration: 5298; Percent complete: 53.0%; Average loss: 0.6487
# Iteration: 5299; Percent complete: 53.0%; Average loss: 0.6709
# Iteration: 5300; Percent complete: 53.0%; Average loss: 0.6706
# Iteration: 5301; Percent complete: 53.0%; Average loss: 0.5635
# Iteration: 5302; Percent complete: 53.0%; Average loss: 0.5646
# Iteration: 5303; Percent complete: 53.0%; Average loss: 0.6817
# Iteration: 5304; Percent complete: 53.0%; Average loss: 0.7170
# Iteration: 5305; Percent complete: 53.0%; Average loss: 0.5197
# Iteration: 5306; Percent complete: 53.1%; Average loss: 0.7153
# Iteration: 5307; Percent complete: 53.1%; Average loss: 0.5699
# Iteration: 5308; Percent complete: 53.1%; Average loss: 0.6671
# Iteration: 5309; Percent complete: 53.1%; Average loss: 0.7654
# Iteration: 5310; Percent complete: 53.1%; Average loss: 0.6911
# Iteration: 5311; Percent complete: 53.1%; Average loss: 0.6173
# Iteration: 5312; Percent complete: 53.1%; Average loss: 0.6660
# Iteration: 5313; Percent complete: 53.1%; Average loss: 0.6083
# Iteration: 5314; Percent complete: 53.1%; Average loss: 0.7410
# Iteration: 5315; Percent complete: 53.1%; Average loss: 0.7074
# Iteration: 5316; Percent complete: 53.2%; Average loss: 0.6759
# Iteration: 5317; Percent complete: 53.2%; Average loss: 0.6266
# Iteration: 5318; Percent complete: 53.2%; Average loss: 0.6686
# Iteration: 5319; Percent complete: 53.2%; Average loss: 0.6620
# Iteration: 5320; Percent complete: 53.2%; Average loss: 0.5744
# Iteration: 5321; Percent complete: 53.2%; Average loss: 0.6625
# Iteration: 5322; Percent complete: 53.2%; Average loss: 0.7950
# Iteration: 5323; Percent complete: 53.2%; Average loss: 0.7062
# Iteration: 5324; Percent complete: 53.2%; Average loss: 0.7486
# Iteration: 5325; Percent complete: 53.2%; Average loss: 0.6518
# Iteration: 5326; Percent complete: 53.3%; Average loss: 0.6827
# Iteration: 5327; Percent complete: 53.3%; Average loss: 0.6535
# Iteration: 5328; Percent complete: 53.3%; Average loss: 0.6892
# Iteration: 5329; Percent complete: 53.3%; Average loss: 0.5412
# Iteration: 5330; Percent complete: 53.3%; Average loss: 0.6815
# Iteration: 5331; Percent complete: 53.3%; Average loss: 0.7063
# Iteration: 5332; Percent complete: 53.3%; Average loss: 0.5497
# Iteration: 5333; Percent complete: 53.3%; Average loss: 0.6126
# Iteration: 5334; Percent complete: 53.3%; Average loss: 0.5390
# Iteration: 5335; Percent complete: 53.3%; Average loss: 0.7652
# Iteration: 5336; Percent complete: 53.4%; Average loss: 0.8202
# Iteration: 5337; Percent complete: 53.4%; Average loss: 0.7050
# Iteration: 5338; Percent complete: 53.4%; Average loss: 0.5595
# Iteration: 5339; Percent complete: 53.4%; Average loss: 0.5855
# Iteration: 5340; Percent complete: 53.4%; Average loss: 0.7702
# Iteration: 5341; Percent complete: 53.4%; Average loss: 0.7064
# Iteration: 5342; Percent complete: 53.4%; Average loss: 0.7138
# Iteration: 5343; Percent complete: 53.4%; Average loss: 0.7811
# Iteration: 5344; Percent complete: 53.4%; Average loss: 0.7191
# Iteration: 5345; Percent complete: 53.4%; Average loss: 0.7607
# Iteration: 5346; Percent complete: 53.5%; Average loss: 0.6176
# Iteration: 5347; Percent complete: 53.5%; Average loss: 0.6588
# Iteration: 5348; Percent complete: 53.5%; Average loss: 0.6737
# Iteration: 5349; Percent complete: 53.5%; Average loss: 0.6732
# Iteration: 5350; Percent complete: 53.5%; Average loss: 0.6750
# Iteration: 5351; Percent complete: 53.5%; Average loss: 0.5428
# Iteration: 5352; Percent complete: 53.5%; Average loss: 0.5154
# Iteration: 5353; Percent complete: 53.5%; Average loss: 0.6175
# Iteration: 5354; Percent complete: 53.5%; Average loss: 0.6914
# Iteration: 5355; Percent complete: 53.5%; Average loss: 0.6907
# Iteration: 5356; Percent complete: 53.6%; Average loss: 0.9122
# Iteration: 5357; Percent complete: 53.6%; Average loss: 0.7713
# Iteration: 5358; Percent complete: 53.6%; Average loss: 0.7270
# Iteration: 5359; Percent complete: 53.6%; Average loss: 0.6546
# Iteration: 5360; Percent complete: 53.6%; Average loss: 0.6421
# Iteration: 5361; Percent complete: 53.6%; Average loss: 0.6923
# Iteration: 5362; Percent complete: 53.6%; Average loss: 0.6115
# Iteration: 5363; Percent complete: 53.6%; Average loss: 0.6165
# Iteration: 5364; Percent complete: 53.6%; Average loss: 0.7006
# Iteration: 5365; Percent complete: 53.6%; Average loss: 0.6793
# Iteration: 5366; Percent complete: 53.7%; Average loss: 0.6270
# Iteration: 5367; Percent complete: 53.7%; Average loss: 0.6301
# Iteration: 5368; Percent complete: 53.7%; Average loss: 0.6714
# Iteration: 5369; Percent complete: 53.7%; Average loss: 0.5475
# Iteration: 5370; Percent complete: 53.7%; Average loss: 0.6291
# Iteration: 5371; Percent complete: 53.7%; Average loss: 0.6279
# Iteration: 5372; Percent complete: 53.7%; Average loss: 0.5669
# Iteration: 5373; Percent complete: 53.7%; Average loss: 0.5675
# Iteration: 5374; Percent complete: 53.7%; Average loss: 0.6923
# Iteration: 5375; Percent complete: 53.8%; Average loss: 0.7244
# Iteration: 5376; Percent complete: 53.8%; Average loss: 0.6674
# Iteration: 5377; Percent complete: 53.8%; Average loss: 0.7557
# Iteration: 5378; Percent complete: 53.8%; Average loss: 0.6632
# Iteration: 5379; Percent complete: 53.8%; Average loss: 0.7566
# Iteration: 5380; Percent complete: 53.8%; Average loss: 0.5882
# Iteration: 5381; Percent complete: 53.8%; Average loss: 0.6538
# Iteration: 5382; Percent complete: 53.8%; Average loss: 0.6605
# Iteration: 5383; Percent complete: 53.8%; Average loss: 0.6274
# Iteration: 5384; Percent complete: 53.8%; Average loss: 0.6820
# Iteration: 5385; Percent complete: 53.8%; Average loss: 0.5829
# Iteration: 5386; Percent complete: 53.9%; Average loss: 0.6123
# Iteration: 5387; Percent complete: 53.9%; Average loss: 0.6456
# Iteration: 5388; Percent complete: 53.9%; Average loss: 0.6790
# Iteration: 5389; Percent complete: 53.9%; Average loss: 0.5596
# Iteration: 5390; Percent complete: 53.9%; Average loss: 0.6596
# Iteration: 5391; Percent complete: 53.9%; Average loss: 0.6002
# Iteration: 5392; Percent complete: 53.9%; Average loss: 0.5561
# Iteration: 5393; Percent complete: 53.9%; Average loss: 0.6627
# Iteration: 5394; Percent complete: 53.9%; Average loss: 0.6753
# Iteration: 5395; Percent complete: 53.9%; Average loss: 0.6319
# Iteration: 5396; Percent complete: 54.0%; Average loss: 0.7364
# Iteration: 5397; Percent complete: 54.0%; Average loss: 0.6644
# Iteration: 5398; Percent complete: 54.0%; Average loss: 0.7928
# Iteration: 5399; Percent complete: 54.0%; Average loss: 0.6361
# Iteration: 5400; Percent complete: 54.0%; Average loss: 0.6972
# Iteration: 5401; Percent complete: 54.0%; Average loss: 0.6470
# Iteration: 5402; Percent complete: 54.0%; Average loss: 0.6465
# Iteration: 5403; Percent complete: 54.0%; Average loss: 0.5882
# Iteration: 5404; Percent complete: 54.0%; Average loss: 0.6099
# Iteration: 5405; Percent complete: 54.0%; Average loss: 0.5454
# Iteration: 5406; Percent complete: 54.1%; Average loss: 0.7024
# Iteration: 5407; Percent complete: 54.1%; Average loss: 0.7309
# Iteration: 5408; Percent complete: 54.1%; Average loss: 0.6392
# Iteration: 5409; Percent complete: 54.1%; Average loss: 0.5304
# Iteration: 5410; Percent complete: 54.1%; Average loss: 0.7130
# Iteration: 5411; Percent complete: 54.1%; Average loss: 0.5816
# Iteration: 5412; Percent complete: 54.1%; Average loss: 0.6417
# Iteration: 5413; Percent complete: 54.1%; Average loss: 0.6709
# Iteration: 5414; Percent complete: 54.1%; Average loss: 0.7005
# Iteration: 5415; Percent complete: 54.1%; Average loss: 0.7975
# Iteration: 5416; Percent complete: 54.2%; Average loss: 0.6449
# Iteration: 5417; Percent complete: 54.2%; Average loss: 0.6577
# Iteration: 5418; Percent complete: 54.2%; Average loss: 0.5990
# Iteration: 5419; Percent complete: 54.2%; Average loss: 0.6189
# Iteration: 5420; Percent complete: 54.2%; Average loss: 0.6973
# Iteration: 5421; Percent complete: 54.2%; Average loss: 0.6183
# Iteration: 5422; Percent complete: 54.2%; Average loss: 0.5351
# Iteration: 5423; Percent complete: 54.2%; Average loss: 0.6690
# Iteration: 5424; Percent complete: 54.2%; Average loss: 0.7652
# Iteration: 5425; Percent complete: 54.2%; Average loss: 0.6429
# Iteration: 5426; Percent complete: 54.3%; Average loss: 0.7047
# Iteration: 5427; Percent complete: 54.3%; Average loss: 0.6020
# Iteration: 5428; Percent complete: 54.3%; Average loss: 0.5993
# Iteration: 5429; Percent complete: 54.3%; Average loss: 0.6673
# Iteration: 5430; Percent complete: 54.3%; Average loss: 0.6672
# Iteration: 5431; Percent complete: 54.3%; Average loss: 0.6826
# Iteration: 5432; Percent complete: 54.3%; Average loss: 0.5870
# Iteration: 5433; Percent complete: 54.3%; Average loss: 0.7563
# Iteration: 5434; Percent complete: 54.3%; Average loss: 0.7110
# Iteration: 5435; Percent complete: 54.4%; Average loss: 0.6897
# Iteration: 5436; Percent complete: 54.4%; Average loss: 0.6608
# Iteration: 5437; Percent complete: 54.4%; Average loss: 0.7302
# Iteration: 5438; Percent complete: 54.4%; Average loss: 0.5985
# Iteration: 5439; Percent complete: 54.4%; Average loss: 0.6204
# Iteration: 5440; Percent complete: 54.4%; Average loss: 0.5547
# Iteration: 5441; Percent complete: 54.4%; Average loss: 0.5604
# Iteration: 5442; Percent complete: 54.4%; Average loss: 0.6414
# Iteration: 5443; Percent complete: 54.4%; Average loss: 0.5783
# Iteration: 5444; Percent complete: 54.4%; Average loss: 0.6808
# Iteration: 5445; Percent complete: 54.4%; Average loss: 0.6336
# Iteration: 5446; Percent complete: 54.5%; Average loss: 0.7506
# Iteration: 5447; Percent complete: 54.5%; Average loss: 0.6669
# Iteration: 5448; Percent complete: 54.5%; Average loss: 0.8052
# Iteration: 5449; Percent complete: 54.5%; Average loss: 0.5956
# Iteration: 5450; Percent complete: 54.5%; Average loss: 0.6213
# Iteration: 5451; Percent complete: 54.5%; Average loss: 0.6206
# Iteration: 5452; Percent complete: 54.5%; Average loss: 0.6893
# Iteration: 5453; Percent complete: 54.5%; Average loss: 0.6065
# Iteration: 5454; Percent complete: 54.5%; Average loss: 0.6430
# Iteration: 5455; Percent complete: 54.5%; Average loss: 0.6056
# Iteration: 5456; Percent complete: 54.6%; Average loss: 0.5459
# Iteration: 5457; Percent complete: 54.6%; Average loss: 0.6525
# Iteration: 5458; Percent complete: 54.6%; Average loss: 0.8281
# Iteration: 5459; Percent complete: 54.6%; Average loss: 0.7109
# Iteration: 5460; Percent complete: 54.6%; Average loss: 0.7017
# Iteration: 5461; Percent complete: 54.6%; Average loss: 0.6600
# Iteration: 5462; Percent complete: 54.6%; Average loss: 0.5418
# Iteration: 5463; Percent complete: 54.6%; Average loss: 0.5407
# Iteration: 5464; Percent complete: 54.6%; Average loss: 0.5495
# Iteration: 5465; Percent complete: 54.6%; Average loss: 0.6320
# Iteration: 5466; Percent complete: 54.7%; Average loss: 0.5913
# Iteration: 5467; Percent complete: 54.7%; Average loss: 0.6514
# Iteration: 5468; Percent complete: 54.7%; Average loss: 0.5919
# Iteration: 5469; Percent complete: 54.7%; Average loss: 0.6459
# Iteration: 5470; Percent complete: 54.7%; Average loss: 0.6316
# Iteration: 5471; Percent complete: 54.7%; Average loss: 0.6285
# Iteration: 5472; Percent complete: 54.7%; Average loss: 0.5533
# Iteration: 5473; Percent complete: 54.7%; Average loss: 0.5577
# Iteration: 5474; Percent complete: 54.7%; Average loss: 0.5769
# Iteration: 5475; Percent complete: 54.8%; Average loss: 0.8172
# Iteration: 5476; Percent complete: 54.8%; Average loss: 0.5613
# Iteration: 5477; Percent complete: 54.8%; Average loss: 0.6251
# Iteration: 5478; Percent complete: 54.8%; Average loss: 0.6163
# Iteration: 5479; Percent complete: 54.8%; Average loss: 0.5358
# Iteration: 5480; Percent complete: 54.8%; Average loss: 0.6371
# Iteration: 5481; Percent complete: 54.8%; Average loss: 0.5763
# Iteration: 5482; Percent complete: 54.8%; Average loss: 0.6707
# Iteration: 5483; Percent complete: 54.8%; Average loss: 0.5857
# Iteration: 5484; Percent complete: 54.8%; Average loss: 0.6815
# Iteration: 5485; Percent complete: 54.9%; Average loss: 0.6520
# Iteration: 5486; Percent complete: 54.9%; Average loss: 0.6469
# Iteration: 5487; Percent complete: 54.9%; Average loss: 0.6461
# Iteration: 5488; Percent complete: 54.9%; Average loss: 0.6261
# Iteration: 5489; Percent complete: 54.9%; Average loss: 0.5541
# Iteration: 5490; Percent complete: 54.9%; Average loss: 0.5731
# Iteration: 5491; Percent complete: 54.9%; Average loss: 0.5644
# Iteration: 5492; Percent complete: 54.9%; Average loss: 0.6493
# Iteration: 5493; Percent complete: 54.9%; Average loss: 0.6005
# Iteration: 5494; Percent complete: 54.9%; Average loss: 0.6420
# Iteration: 5495; Percent complete: 54.9%; Average loss: 0.7086
# Iteration: 5496; Percent complete: 55.0%; Average loss: 0.6474
# Iteration: 5497; Percent complete: 55.0%; Average loss: 0.6492
# Iteration: 5498; Percent complete: 55.0%; Average loss: 0.7461
# Iteration: 5499; Percent complete: 55.0%; Average loss: 0.5947
# Iteration: 5500; Percent complete: 55.0%; Average loss: 0.5658
# Iteration: 5501; Percent complete: 55.0%; Average loss: 0.6671
# Iteration: 5502; Percent complete: 55.0%; Average loss: 0.5602
# Iteration: 5503; Percent complete: 55.0%; Average loss: 0.7057
# Iteration: 5504; Percent complete: 55.0%; Average loss: 0.5370
# Iteration: 5505; Percent complete: 55.0%; Average loss: 0.6256
# Iteration: 5506; Percent complete: 55.1%; Average loss: 0.6688
# Iteration: 5507; Percent complete: 55.1%; Average loss: 0.4799
# Iteration: 5508; Percent complete: 55.1%; Average loss: 0.6780
# Iteration: 5509; Percent complete: 55.1%; Average loss: 0.5543
# Iteration: 5510; Percent complete: 55.1%; Average loss: 0.5697
# Iteration: 5511; Percent complete: 55.1%; Average loss: 0.5723
# Iteration: 5512; Percent complete: 55.1%; Average loss: 0.6801
# Iteration: 5513; Percent complete: 55.1%; Average loss: 0.5579
# Iteration: 5514; Percent complete: 55.1%; Average loss: 0.6290
# Iteration: 5515; Percent complete: 55.1%; Average loss: 0.6091
# Iteration: 5516; Percent complete: 55.2%; Average loss: 0.7395
# Iteration: 5517; Percent complete: 55.2%; Average loss: 0.7094
# Iteration: 5518; Percent complete: 55.2%; Average loss: 0.5690
# Iteration: 5519; Percent complete: 55.2%; Average loss: 0.6406
# Iteration: 5520; Percent complete: 55.2%; Average loss: 0.7054
# Iteration: 5521; Percent complete: 55.2%; Average loss: 0.6394
# Iteration: 5522; Percent complete: 55.2%; Average loss: 0.5877
# Iteration: 5523; Percent complete: 55.2%; Average loss: 0.5867
# Iteration: 5524; Percent complete: 55.2%; Average loss: 0.7022
# Iteration: 5525; Percent complete: 55.2%; Average loss: 0.6694
# Iteration: 5526; Percent complete: 55.3%; Average loss: 0.5198
# Iteration: 5527; Percent complete: 55.3%; Average loss: 0.5946
# Iteration: 5528; Percent complete: 55.3%; Average loss: 0.6406
# Iteration: 5529; Percent complete: 55.3%; Average loss: 0.6997
# Iteration: 5530; Percent complete: 55.3%; Average loss: 0.6292
# Iteration: 5531; Percent complete: 55.3%; Average loss: 0.6692
# Iteration: 5532; Percent complete: 55.3%; Average loss: 0.7044
# Iteration: 5533; Percent complete: 55.3%; Average loss: 0.6072
# Iteration: 5534; Percent complete: 55.3%; Average loss: 0.6173
# Iteration: 5535; Percent complete: 55.4%; Average loss: 0.5640
# Iteration: 5536; Percent complete: 55.4%; Average loss: 0.6252
# Iteration: 5537; Percent complete: 55.4%; Average loss: 0.6555
# Iteration: 5538; Percent complete: 55.4%; Average loss: 0.6030
# Iteration: 5539; Percent complete: 55.4%; Average loss: 0.6193
# Iteration: 5540; Percent complete: 55.4%; Average loss: 0.6765
# Iteration: 5541; Percent complete: 55.4%; Average loss: 0.5873
# Iteration: 5542; Percent complete: 55.4%; Average loss: 0.5906
# Iteration: 5543; Percent complete: 55.4%; Average loss: 0.5473
# Iteration: 5544; Percent complete: 55.4%; Average loss: 0.7212
# Iteration: 5545; Percent complete: 55.5%; Average loss: 0.6264
# Iteration: 5546; Percent complete: 55.5%; Average loss: 0.6418
# Iteration: 5547; Percent complete: 55.5%; Average loss: 0.6775
# Iteration: 5548; Percent complete: 55.5%; Average loss: 0.5757
# Iteration: 5549; Percent complete: 55.5%; Average loss: 0.6098
# Iteration: 5550; Percent complete: 55.5%; Average loss: 0.6418
# Iteration: 5551; Percent complete: 55.5%; Average loss: 0.5410
# Iteration: 5552; Percent complete: 55.5%; Average loss: 0.7071
# Iteration: 5553; Percent complete: 55.5%; Average loss: 0.5420
# Iteration: 5554; Percent complete: 55.5%; Average loss: 0.6359
# Iteration: 5555; Percent complete: 55.5%; Average loss: 0.6724
# Iteration: 5556; Percent complete: 55.6%; Average loss: 0.5683
# Iteration: 5557; Percent complete: 55.6%; Average loss: 0.5522
# Iteration: 5558; Percent complete: 55.6%; Average loss: 0.6183
# Iteration: 5559; Percent complete: 55.6%; Average loss: 0.6656
# Iteration: 5560; Percent complete: 55.6%; Average loss: 0.6225
# Iteration: 5561; Percent complete: 55.6%; Average loss: 0.5130
# Iteration: 5562; Percent complete: 55.6%; Average loss: 0.6825
# Iteration: 5563; Percent complete: 55.6%; Average loss: 0.6059
# Iteration: 5564; Percent complete: 55.6%; Average loss: 0.5240
# Iteration: 5565; Percent complete: 55.6%; Average loss: 0.5051
# Iteration: 5566; Percent complete: 55.7%; Average loss: 0.5388
# Iteration: 5567; Percent complete: 55.7%; Average loss: 0.6580
# Iteration: 5568; Percent complete: 55.7%; Average loss: 0.6517
# Iteration: 5569; Percent complete: 55.7%; Average loss: 0.5518
# Iteration: 5570; Percent complete: 55.7%; Average loss: 0.6051
# Iteration: 5571; Percent complete: 55.7%; Average loss: 0.5340
# Iteration: 5572; Percent complete: 55.7%; Average loss: 0.5684
# Iteration: 5573; Percent complete: 55.7%; Average loss: 0.7076
# Iteration: 5574; Percent complete: 55.7%; Average loss: 0.6648
# Iteration: 5575; Percent complete: 55.8%; Average loss: 0.5895
# Iteration: 5576; Percent complete: 55.8%; Average loss: 0.5570
# Iteration: 5577; Percent complete: 55.8%; Average loss: 0.5432
# Iteration: 5578; Percent complete: 55.8%; Average loss: 0.6322
# Iteration: 5579; Percent complete: 55.8%; Average loss: 0.5962
# Iteration: 5580; Percent complete: 55.8%; Average loss: 0.5116
# Iteration: 5581; Percent complete: 55.8%; Average loss: 0.6327
# Iteration: 5582; Percent complete: 55.8%; Average loss: 0.5416
# Iteration: 5583; Percent complete: 55.8%; Average loss: 0.5100
# Iteration: 5584; Percent complete: 55.8%; Average loss: 0.5224
# Iteration: 5585; Percent complete: 55.9%; Average loss: 0.5839
# Iteration: 5586; Percent complete: 55.9%; Average loss: 0.6228
# Iteration: 5587; Percent complete: 55.9%; Average loss: 0.5532
# Iteration: 5588; Percent complete: 55.9%; Average loss: 0.6761
# Iteration: 5589; Percent complete: 55.9%; Average loss: 0.6241
# Iteration: 5590; Percent complete: 55.9%; Average loss: 0.6547
# Iteration: 5591; Percent complete: 55.9%; Average loss: 0.6340
# Iteration: 5592; Percent complete: 55.9%; Average loss: 0.5875
# Iteration: 5593; Percent complete: 55.9%; Average loss: 0.5467
# Iteration: 5594; Percent complete: 55.9%; Average loss: 0.5952
# Iteration: 5595; Percent complete: 56.0%; Average loss: 0.5997
# Iteration: 5596; Percent complete: 56.0%; Average loss: 0.5964
# Iteration: 5597; Percent complete: 56.0%; Average loss: 0.5986
# Iteration: 5598; Percent complete: 56.0%; Average loss: 0.5465
# Iteration: 5599; Percent complete: 56.0%; Average loss: 0.5933
# Iteration: 5600; Percent complete: 56.0%; Average loss: 0.6948
# Iteration: 5601; Percent complete: 56.0%; Average loss: 0.5825
# Iteration: 5602; Percent complete: 56.0%; Average loss: 0.5842
# Iteration: 5603; Percent complete: 56.0%; Average loss: 0.5178
# Iteration: 5604; Percent complete: 56.0%; Average loss: 0.6485
# Iteration: 5605; Percent complete: 56.0%; Average loss: 0.5815
# Iteration: 5606; Percent complete: 56.1%; Average loss: 0.6575
# Iteration: 5607; Percent complete: 56.1%; Average loss: 0.5948
# Iteration: 5608; Percent complete: 56.1%; Average loss: 0.6066
# Iteration: 5609; Percent complete: 56.1%; Average loss: 0.4914
# Iteration: 5610; Percent complete: 56.1%; Average loss: 0.5756
# Iteration: 5611; Percent complete: 56.1%; Average loss: 0.6181
# Iteration: 5612; Percent complete: 56.1%; Average loss: 0.6510
# Iteration: 5613; Percent complete: 56.1%; Average loss: 0.6227
# Iteration: 5614; Percent complete: 56.1%; Average loss: 0.5984
# Iteration: 5615; Percent complete: 56.1%; Average loss: 0.6311
# Iteration: 5616; Percent complete: 56.2%; Average loss: 0.6017
# Iteration: 5617; Percent complete: 56.2%; Average loss: 0.6329
# Iteration: 5618; Percent complete: 56.2%; Average loss: 0.5929
# Iteration: 5619; Percent complete: 56.2%; Average loss: 0.5513
# Iteration: 5620; Percent complete: 56.2%; Average loss: 0.6190
# Iteration: 5621; Percent complete: 56.2%; Average loss: 0.6418
# Iteration: 5622; Percent complete: 56.2%; Average loss: 0.6497
# Iteration: 5623; Percent complete: 56.2%; Average loss: 0.6073
# Iteration: 5624; Percent complete: 56.2%; Average loss: 0.6259
# Iteration: 5625; Percent complete: 56.2%; Average loss: 0.5866
# Iteration: 5626; Percent complete: 56.3%; Average loss: 0.5523
# Iteration: 5627; Percent complete: 56.3%; Average loss: 0.5692
# Iteration: 5628; Percent complete: 56.3%; Average loss: 0.6688
# Iteration: 5629; Percent complete: 56.3%; Average loss: 0.6574
# Iteration: 5630; Percent complete: 56.3%; Average loss: 0.6856
# Iteration: 5631; Percent complete: 56.3%; Average loss: 0.5479
# Iteration: 5632; Percent complete: 56.3%; Average loss: 0.5776
# Iteration: 5633; Percent complete: 56.3%; Average loss: 0.5700
# Iteration: 5634; Percent complete: 56.3%; Average loss: 0.6190
# Iteration: 5635; Percent complete: 56.4%; Average loss: 0.7057
# Iteration: 5636; Percent complete: 56.4%; Average loss: 0.5013
# Iteration: 5637; Percent complete: 56.4%; Average loss: 0.6399
# Iteration: 5638; Percent complete: 56.4%; Average loss: 0.6181
# Iteration: 5639; Percent complete: 56.4%; Average loss: 0.4856
# Iteration: 5640; Percent complete: 56.4%; Average loss: 0.5085
# Iteration: 5641; Percent complete: 56.4%; Average loss: 0.6143
# Iteration: 5642; Percent complete: 56.4%; Average loss: 0.5358
# Iteration: 5643; Percent complete: 56.4%; Average loss: 0.5929
# Iteration: 5644; Percent complete: 56.4%; Average loss: 0.6293
# Iteration: 5645; Percent complete: 56.5%; Average loss: 0.6891
# Iteration: 5646; Percent complete: 56.5%; Average loss: 0.5459
# Iteration: 5647; Percent complete: 56.5%; Average loss: 0.6101
# Iteration: 5648; Percent complete: 56.5%; Average loss: 0.5638
# Iteration: 5649; Percent complete: 56.5%; Average loss: 0.5563
# Iteration: 5650; Percent complete: 56.5%; Average loss: 0.6513
# Iteration: 5651; Percent complete: 56.5%; Average loss: 0.6925
# Iteration: 5652; Percent complete: 56.5%; Average loss: 0.5697
# Iteration: 5653; Percent complete: 56.5%; Average loss: 0.5846
# Iteration: 5654; Percent complete: 56.5%; Average loss: 0.6530
# Iteration: 5655; Percent complete: 56.5%; Average loss: 0.5476
# Iteration: 5656; Percent complete: 56.6%; Average loss: 0.6289
# Iteration: 5657; Percent complete: 56.6%; Average loss: 0.5573
# Iteration: 5658; Percent complete: 56.6%; Average loss: 0.5675
# Iteration: 5659; Percent complete: 56.6%; Average loss: 0.5178
# Iteration: 5660; Percent complete: 56.6%; Average loss: 0.5900
# Iteration: 5661; Percent complete: 56.6%; Average loss: 0.5795
# Iteration: 5662; Percent complete: 56.6%; Average loss: 0.5866
# Iteration: 5663; Percent complete: 56.6%; Average loss: 0.5602
# Iteration: 5664; Percent complete: 56.6%; Average loss: 0.6261
# Iteration: 5665; Percent complete: 56.6%; Average loss: 0.5605
# Iteration: 5666; Percent complete: 56.7%; Average loss: 0.5630
# Iteration: 5667; Percent complete: 56.7%; Average loss: 0.6096
# Iteration: 5668; Percent complete: 56.7%; Average loss: 0.5522
# Iteration: 5669; Percent complete: 56.7%; Average loss: 0.5775
# Iteration: 5670; Percent complete: 56.7%; Average loss: 0.5457
# Iteration: 5671; Percent complete: 56.7%; Average loss: 0.6607
# Iteration: 5672; Percent complete: 56.7%; Average loss: 0.6965
# Iteration: 5673; Percent complete: 56.7%; Average loss: 0.5655
# Iteration: 5674; Percent complete: 56.7%; Average loss: 0.5681
# Iteration: 5675; Percent complete: 56.8%; Average loss: 0.6429
# Iteration: 5676; Percent complete: 56.8%; Average loss: 0.6852
# Iteration: 5677; Percent complete: 56.8%; Average loss: 0.5725
# Iteration: 5678; Percent complete: 56.8%; Average loss: 0.6154
# Iteration: 5679; Percent complete: 56.8%; Average loss: 0.6661
# Iteration: 5680; Percent complete: 56.8%; Average loss: 0.5482
# Iteration: 5681; Percent complete: 56.8%; Average loss: 0.5999
# Iteration: 5682; Percent complete: 56.8%; Average loss: 0.5721
# Iteration: 5683; Percent complete: 56.8%; Average loss: 0.5658
# Iteration: 5684; Percent complete: 56.8%; Average loss: 0.5673
# Iteration: 5685; Percent complete: 56.9%; Average loss: 0.5814
# Iteration: 5686; Percent complete: 56.9%; Average loss: 0.5550
# Iteration: 5687; Percent complete: 56.9%; Average loss: 0.5671
# Iteration: 5688; Percent complete: 56.9%; Average loss: 0.5264
# Iteration: 5689; Percent complete: 56.9%; Average loss: 0.5781
# Iteration: 5690; Percent complete: 56.9%; Average loss: 0.5749
# Iteration: 5691; Percent complete: 56.9%; Average loss: 0.5263
# Iteration: 5692; Percent complete: 56.9%; Average loss: 0.4869
# Iteration: 5693; Percent complete: 56.9%; Average loss: 0.6067
# Iteration: 5694; Percent complete: 56.9%; Average loss: 0.6163
# Iteration: 5695; Percent complete: 57.0%; Average loss: 0.5534
# Iteration: 5696; Percent complete: 57.0%; Average loss: 0.6513
# Iteration: 5697; Percent complete: 57.0%; Average loss: 0.5020
# Iteration: 5698; Percent complete: 57.0%; Average loss: 0.5556
# Iteration: 5699; Percent complete: 57.0%; Average loss: 0.7216
# Iteration: 5700; Percent complete: 57.0%; Average loss: 0.4874
# Iteration: 5701; Percent complete: 57.0%; Average loss: 0.5695
# Iteration: 5702; Percent complete: 57.0%; Average loss: 0.5939
# Iteration: 5703; Percent complete: 57.0%; Average loss: 0.7019
# Iteration: 5704; Percent complete: 57.0%; Average loss: 0.7349
# Iteration: 5705; Percent complete: 57.0%; Average loss: 0.5573
# Iteration: 5706; Percent complete: 57.1%; Average loss: 0.6817
# Iteration: 5707; Percent complete: 57.1%; Average loss: 0.6140
# Iteration: 5708; Percent complete: 57.1%; Average loss: 0.6049
# Iteration: 5709; Percent complete: 57.1%; Average loss: 0.6086
# Iteration: 5710; Percent complete: 57.1%; Average loss: 0.5011
# Iteration: 5711; Percent complete: 57.1%; Average loss: 0.5163
# Iteration: 5712; Percent complete: 57.1%; Average loss: 0.5872
# Iteration: 5713; Percent complete: 57.1%; Average loss: 0.4853
# Iteration: 5714; Percent complete: 57.1%; Average loss: 0.6264
# Iteration: 5715; Percent complete: 57.1%; Average loss: 0.6214
# Iteration: 5716; Percent complete: 57.2%; Average loss: 0.4761
# Iteration: 5717; Percent complete: 57.2%; Average loss: 0.6075
# Iteration: 5718; Percent complete: 57.2%; Average loss: 0.5767
# Iteration: 5719; Percent complete: 57.2%; Average loss: 0.6101
# Iteration: 5720; Percent complete: 57.2%; Average loss: 0.5699
# Iteration: 5721; Percent complete: 57.2%; Average loss: 0.5199
# Iteration: 5722; Percent complete: 57.2%; Average loss: 0.6091
# Iteration: 5723; Percent complete: 57.2%; Average loss: 0.7025
# Iteration: 5724; Percent complete: 57.2%; Average loss: 0.5823
# Iteration: 5725; Percent complete: 57.2%; Average loss: 0.4973
# Iteration: 5726; Percent complete: 57.3%; Average loss: 0.6579
# Iteration: 5727; Percent complete: 57.3%; Average loss: 0.6325
# Iteration: 5728; Percent complete: 57.3%; Average loss: 0.4853
# Iteration: 5729; Percent complete: 57.3%; Average loss: 0.5888
# Iteration: 5730; Percent complete: 57.3%; Average loss: 0.5330
# Iteration: 5731; Percent complete: 57.3%; Average loss: 0.6018
# Iteration: 5732; Percent complete: 57.3%; Average loss: 0.4845
# Iteration: 5733; Percent complete: 57.3%; Average loss: 0.4860
# Iteration: 5734; Percent complete: 57.3%; Average loss: 0.5351
# Iteration: 5735; Percent complete: 57.4%; Average loss: 0.5788
# Iteration: 5736; Percent complete: 57.4%; Average loss: 0.6002
# Iteration: 5737; Percent complete: 57.4%; Average loss: 0.6616
# Iteration: 5738; Percent complete: 57.4%; Average loss: 0.5980
# Iteration: 5739; Percent complete: 57.4%; Average loss: 0.4852
# Iteration: 5740; Percent complete: 57.4%; Average loss: 0.5297
# Iteration: 5741; Percent complete: 57.4%; Average loss: 0.6530
# Iteration: 5742; Percent complete: 57.4%; Average loss: 0.5501
# Iteration: 5743; Percent complete: 57.4%; Average loss: 0.5278
# Iteration: 5744; Percent complete: 57.4%; Average loss: 0.5218
# Iteration: 5745; Percent complete: 57.5%; Average loss: 0.6420
# Iteration: 5746; Percent complete: 57.5%; Average loss: 0.5943
# Iteration: 5747; Percent complete: 57.5%; Average loss: 0.5801
# Iteration: 5748; Percent complete: 57.5%; Average loss: 0.4729
# Iteration: 5749; Percent complete: 57.5%; Average loss: 0.5768
# Iteration: 5750; Percent complete: 57.5%; Average loss: 0.5051
# Iteration: 5751; Percent complete: 57.5%; Average loss: 0.5498
# Iteration: 5752; Percent complete: 57.5%; Average loss: 0.5588
# Iteration: 5753; Percent complete: 57.5%; Average loss: 0.5727
# Iteration: 5754; Percent complete: 57.5%; Average loss: 0.5917
# Iteration: 5755; Percent complete: 57.6%; Average loss: 0.5878
# Iteration: 5756; Percent complete: 57.6%; Average loss: 0.6048
# Iteration: 5757; Percent complete: 57.6%; Average loss: 0.5460
# Iteration: 5758; Percent complete: 57.6%; Average loss: 0.5549
# Iteration: 5759; Percent complete: 57.6%; Average loss: 0.6044
# Iteration: 5760; Percent complete: 57.6%; Average loss: 0.5633
# Iteration: 5761; Percent complete: 57.6%; Average loss: 0.6323
# Iteration: 5762; Percent complete: 57.6%; Average loss: 0.4910
# ...
# Iteration: 9749; Percent complete: 97.5%; Average loss: 0.2796
# Iteration: 9750; Percent complete: 97.5%; Average loss: 0.2603
# Iteration: 9751; Percent complete: 97.5%; Average loss: 0.2683
# Iteration: 9752; Percent complete: 97.5%; Average loss: 0.2770
# Iteration: 9753; Percent complete: 97.5%; Average loss: 0.3544
# Iteration: 9754; Percent complete: 97.5%; Average loss: 0.3242
# Iteration: 9755; Percent complete: 97.5%; Average loss: 0.3073
# Iteration: 9756; Percent complete: 97.6%; Average loss: 0.3173
# Iteration: 9757; Percent complete: 97.6%; Average loss: 0.2724
# Iteration: 9758; Percent complete: 97.6%; Average loss: 0.2587
# Iteration: 9759; Percent complete: 97.6%; Average loss: 0.2603
# Iteration: 9760; Percent complete: 97.6%; Average loss: 0.1960
# Iteration: 9761; Percent complete: 97.6%; Average loss: 0.3683
# Iteration: 9762; Percent complete: 97.6%; Average loss: 0.3354
# Iteration: 9763; Percent complete: 97.6%; Average loss: 0.3200
# Iteration: 9764; Percent complete: 97.6%; Average loss: 0.2773
# Iteration: 9765; Percent complete: 97.7%; Average loss: 0.3051
# Iteration: 9766; Percent complete: 97.7%; Average loss: 0.2364
# Iteration: 9767; Percent complete: 97.7%; Average loss: 0.2693
# Iteration: 9768; Percent complete: 97.7%; Average loss: 0.3463
# Iteration: 9769; Percent complete: 97.7%; Average loss: 0.2809
# Iteration: 9770; Percent complete: 97.7%; Average loss: 0.3505
# Iteration: 9771; Percent complete: 97.7%; Average loss: 0.2908
# Iteration: 9772; Percent complete: 97.7%; Average loss: 0.3229
# Iteration: 9773; Percent complete: 97.7%; Average loss: 0.2580
# Iteration: 9774; Percent complete: 97.7%; Average loss: 0.2869
# Iteration: 9775; Percent complete: 97.8%; Average loss: 0.3392
# Iteration: 9776; Percent complete: 97.8%; Average loss: 0.2648
# Iteration: 9777; Percent complete: 97.8%; Average loss: 0.2511
# Iteration: 9778; Percent complete: 97.8%; Average loss: 0.2814
# Iteration: 9779; Percent complete: 97.8%; Average loss: 0.2892
# Iteration: 9780; Percent complete: 97.8%; Average loss: 0.2836
# Iteration: 9781; Percent complete: 97.8%; Average loss: 0.2569
# Iteration: 9782; Percent complete: 97.8%; Average loss: 0.3021
# Iteration: 9783; Percent complete: 97.8%; Average loss: 0.3008
# Iteration: 9784; Percent complete: 97.8%; Average loss: 0.3738
# Iteration: 9785; Percent complete: 97.9%; Average loss: 0.3040
# Iteration: 9786; Percent complete: 97.9%; Average loss: 0.3422
# Iteration: 9787; Percent complete: 97.9%; Average loss: 0.3572
# Iteration: 9788; Percent complete: 97.9%; Average loss: 0.3205
# Iteration: 9789; Percent complete: 97.9%; Average loss: 0.3212
# Iteration: 9790; Percent complete: 97.9%; Average loss: 0.3168
# Iteration: 9791; Percent complete: 97.9%; Average loss: 0.2177
# Iteration: 9792; Percent complete: 97.9%; Average loss: 0.2871
# Iteration: 9793; Percent complete: 97.9%; Average loss: 0.2915
# Iteration: 9794; Percent complete: 97.9%; Average loss: 0.2170
# Iteration: 9795; Percent complete: 98.0%; Average loss: 0.2860
# Iteration: 9796; Percent complete: 98.0%; Average loss: 0.2628
# Iteration: 9797; Percent complete: 98.0%; Average loss: 0.2670
# Iteration: 9798; Percent complete: 98.0%; Average loss: 0.2687
# Iteration: 9799; Percent complete: 98.0%; Average loss: 0.2870
# Iteration: 9800; Percent complete: 98.0%; Average loss: 0.3452
# Iteration: 9801; Percent complete: 98.0%; Average loss: 0.3239
# Iteration: 9802; Percent complete: 98.0%; Average loss: 0.3662
# Iteration: 9803; Percent complete: 98.0%; Average loss: 0.3086
# Iteration: 9804; Percent complete: 98.0%; Average loss: 0.2548
# Iteration: 9805; Percent complete: 98.0%; Average loss: 0.3306
# Iteration: 9806; Percent complete: 98.1%; Average loss: 0.2057
# Iteration: 9807; Percent complete: 98.1%; Average loss: 0.2835
# Iteration: 9808; Percent complete: 98.1%; Average loss: 0.2186
# Iteration: 9809; Percent complete: 98.1%; Average loss: 0.2637
# Iteration: 9810; Percent complete: 98.1%; Average loss: 0.3624
# Iteration: 9811; Percent complete: 98.1%; Average loss: 0.2280
# Iteration: 9812; Percent complete: 98.1%; Average loss: 0.3265
# Iteration: 9813; Percent complete: 98.1%; Average loss: 0.2530
# Iteration: 9814; Percent complete: 98.1%; Average loss: 0.2345
# Iteration: 9815; Percent complete: 98.2%; Average loss: 0.2402
# Iteration: 9816; Percent complete: 98.2%; Average loss: 0.2595
# Iteration: 9817; Percent complete: 98.2%; Average loss: 0.2893
# Iteration: 9818; Percent complete: 98.2%; Average loss: 0.2426
# Iteration: 9819; Percent complete: 98.2%; Average loss: 0.2697
# Iteration: 9820; Percent complete: 98.2%; Average loss: 0.2536
# Iteration: 9821; Percent complete: 98.2%; Average loss: 0.2874
# Iteration: 9822; Percent complete: 98.2%; Average loss: 0.2314
# Iteration: 9823; Percent complete: 98.2%; Average loss: 0.3297
# Iteration: 9824; Percent complete: 98.2%; Average loss: 0.3202
# Iteration: 9825; Percent complete: 98.2%; Average loss: 0.2810
# Iteration: 9826; Percent complete: 98.3%; Average loss: 0.2532
# Iteration: 9827; Percent complete: 98.3%; Average loss: 0.3416
# Iteration: 9828; Percent complete: 98.3%; Average loss: 0.2786
# Iteration: 9829; Percent complete: 98.3%; Average loss: 0.2736
# Iteration: 9830; Percent complete: 98.3%; Average loss: 0.2738
# Iteration: 9831; Percent complete: 98.3%; Average loss: 0.3088
# Iteration: 9832; Percent complete: 98.3%; Average loss: 0.2695
# Iteration: 9833; Percent complete: 98.3%; Average loss: 0.2902
# Iteration: 9834; Percent complete: 98.3%; Average loss: 0.3050
# Iteration: 9835; Percent complete: 98.4%; Average loss: 0.2742
# Iteration: 9836; Percent complete: 98.4%; Average loss: 0.2691
# Iteration: 9837; Percent complete: 98.4%; Average loss: 0.2661
# Iteration: 9838; Percent complete: 98.4%; Average loss: 0.2227
# Iteration: 9839; Percent complete: 98.4%; Average loss: 0.3682
# Iteration: 9840; Percent complete: 98.4%; Average loss: 0.2924
# Iteration: 9841; Percent complete: 98.4%; Average loss: 0.4012
# Iteration: 9842; Percent complete: 98.4%; Average loss: 0.2098
# Iteration: 9843; Percent complete: 98.4%; Average loss: 0.3437
# Iteration: 9844; Percent complete: 98.4%; Average loss: 0.3646
# Iteration: 9845; Percent complete: 98.5%; Average loss: 0.2950
# Iteration: 9846; Percent complete: 98.5%; Average loss: 0.3279
# Iteration: 9847; Percent complete: 98.5%; Average loss: 0.3313
# Iteration: 9848; Percent complete: 98.5%; Average loss: 0.2939
# Iteration: 9849; Percent complete: 98.5%; Average loss: 0.2888
# Iteration: 9850; Percent complete: 98.5%; Average loss: 0.2411
# Iteration: 9851; Percent complete: 98.5%; Average loss: 0.2166
# Iteration: 9852; Percent complete: 98.5%; Average loss: 0.2706
# Iteration: 9853; Percent complete: 98.5%; Average loss: 0.3030
# Iteration: 9854; Percent complete: 98.5%; Average loss: 0.3102
# Iteration: 9855; Percent complete: 98.6%; Average loss: 0.3010
# Iteration: 9856; Percent complete: 98.6%; Average loss: 0.2560
# Iteration: 9857; Percent complete: 98.6%; Average loss: 0.2134
# Iteration: 9858; Percent complete: 98.6%; Average loss: 0.2540
# Iteration: 9859; Percent complete: 98.6%; Average loss: 0.2807
# Iteration: 9860; Percent complete: 98.6%; Average loss: 0.2088
# Iteration: 9861; Percent complete: 98.6%; Average loss: 0.2923
# Iteration: 9862; Percent complete: 98.6%; Average loss: 0.2712
# Iteration: 9863; Percent complete: 98.6%; Average loss: 0.3486
# Iteration: 9864; Percent complete: 98.6%; Average loss: 0.3189
# Iteration: 9865; Percent complete: 98.7%; Average loss: 0.3147
# Iteration: 9866; Percent complete: 98.7%; Average loss: 0.2669
# Iteration: 9867; Percent complete: 98.7%; Average loss: 0.2484
# Iteration: 9868; Percent complete: 98.7%; Average loss: 0.3203
# Iteration: 9869; Percent complete: 98.7%; Average loss: 0.2711
# Iteration: 9870; Percent complete: 98.7%; Average loss: 0.2019
# Iteration: 9871; Percent complete: 98.7%; Average loss: 0.2861
# Iteration: 9872; Percent complete: 98.7%; Average loss: 0.3214
# Iteration: 9873; Percent complete: 98.7%; Average loss: 0.2343
# Iteration: 9874; Percent complete: 98.7%; Average loss: 0.2227
# Iteration: 9875; Percent complete: 98.8%; Average loss: 0.2395
# Iteration: 9876; Percent complete: 98.8%; Average loss: 0.2663
# Iteration: 9877; Percent complete: 98.8%; Average loss: 0.2329
# Iteration: 9878; Percent complete: 98.8%; Average loss: 0.2509
# Iteration: 9879; Percent complete: 98.8%; Average loss: 0.2632
# Iteration: 9880; Percent complete: 98.8%; Average loss: 0.3123
# Iteration: 9881; Percent complete: 98.8%; Average loss: 0.2778
# Iteration: 9882; Percent complete: 98.8%; Average loss: 0.2982
# Iteration: 9883; Percent complete: 98.8%; Average loss: 0.2903
# Iteration: 9884; Percent complete: 98.8%; Average loss: 0.3725
# Iteration: 9885; Percent complete: 98.9%; Average loss: 0.2671
# Iteration: 9886; Percent complete: 98.9%; Average loss: 0.2517
# Iteration: 9887; Percent complete: 98.9%; Average loss: 0.2446
# Iteration: 9888; Percent complete: 98.9%; Average loss: 0.3434
# Iteration: 9889; Percent complete: 98.9%; Average loss: 0.3552
# Iteration: 9890; Percent complete: 98.9%; Average loss: 0.3376
# Iteration: 9891; Percent complete: 98.9%; Average loss: 0.3687
# Iteration: 9892; Percent complete: 98.9%; Average loss: 0.2771
# Iteration: 9893; Percent complete: 98.9%; Average loss: 0.2946
# Iteration: 9894; Percent complete: 98.9%; Average loss: 0.2971
# Iteration: 9895; Percent complete: 99.0%; Average loss: 0.3272
# Iteration: 9896; Percent complete: 99.0%; Average loss: 0.2760
# Iteration: 9897; Percent complete: 99.0%; Average loss: 0.3109
# Iteration: 9898; Percent complete: 99.0%; Average loss: 0.2783
# Iteration: 9899; Percent complete: 99.0%; Average loss: 0.2469
# Iteration: 9900; Percent complete: 99.0%; Average loss: 0.2171
# Iteration: 9901; Percent complete: 99.0%; Average loss: 0.3202
# Iteration: 9902; Percent complete: 99.0%; Average loss: 0.3426
# Iteration: 9903; Percent complete: 99.0%; Average loss: 0.3185
# Iteration: 9904; Percent complete: 99.0%; Average loss: 0.3161
# Iteration: 9905; Percent complete: 99.1%; Average loss: 0.2315
# Iteration: 9906; Percent complete: 99.1%; Average loss: 0.2803
# Iteration: 9907; Percent complete: 99.1%; Average loss: 0.3413
# Iteration: 9908; Percent complete: 99.1%; Average loss: 0.2734
# Iteration: 9909; Percent complete: 99.1%; Average loss: 0.3044
# Iteration: 9910; Percent complete: 99.1%; Average loss: 0.2211
# Iteration: 9911; Percent complete: 99.1%; Average loss: 0.2656
# Iteration: 9912; Percent complete: 99.1%; Average loss: 0.2917
# Iteration: 9913; Percent complete: 99.1%; Average loss: 0.2863
# Iteration: 9914; Percent complete: 99.1%; Average loss: 0.3734
# Iteration: 9915; Percent complete: 99.2%; Average loss: 0.3059
# Iteration: 9916; Percent complete: 99.2%; Average loss: 0.2660
# Iteration: 9917; Percent complete: 99.2%; Average loss: 0.3223
# Iteration: 9918; Percent complete: 99.2%; Average loss: 0.2983
# Iteration: 9919; Percent complete: 99.2%; Average loss: 0.2485
# Iteration: 9920; Percent complete: 99.2%; Average loss: 0.3452
# Iteration: 9921; Percent complete: 99.2%; Average loss: 0.3791
# Iteration: 9922; Percent complete: 99.2%; Average loss: 0.2761
# Iteration: 9923; Percent complete: 99.2%; Average loss: 0.2907
# Iteration: 9924; Percent complete: 99.2%; Average loss: 0.2723
# Iteration: 9925; Percent complete: 99.2%; Average loss: 0.3072
# Iteration: 9926; Percent complete: 99.3%; Average loss: 0.2616
# Iteration: 9927; Percent complete: 99.3%; Average loss: 0.2255
# Iteration: 9928; Percent complete: 99.3%; Average loss: 0.2764
# Iteration: 9929; Percent complete: 99.3%; Average loss: 0.3716
# Iteration: 9930; Percent complete: 99.3%; Average loss: 0.2685
# Iteration: 9931; Percent complete: 99.3%; Average loss: 0.2844
# Iteration: 9932; Percent complete: 99.3%; Average loss: 0.2880
# Iteration: 9933; Percent complete: 99.3%; Average loss: 0.2733
# Iteration: 9934; Percent complete: 99.3%; Average loss: 0.3042
# Iteration: 9935; Percent complete: 99.4%; Average loss: 0.3178
# Iteration: 9936; Percent complete: 99.4%; Average loss: 0.2851
# Iteration: 9937; Percent complete: 99.4%; Average loss: 0.3169
# Iteration: 9938; Percent complete: 99.4%; Average loss: 0.1870
# Iteration: 9939; Percent complete: 99.4%; Average loss: 0.3109
# Iteration: 9940; Percent complete: 99.4%; Average loss: 0.2531
# Iteration: 9941; Percent complete: 99.4%; Average loss: 0.3564
# Iteration: 9942; Percent complete: 99.4%; Average loss: 0.3346
# Iteration: 9943; Percent complete: 99.4%; Average loss: 0.3072
# Iteration: 9944; Percent complete: 99.4%; Average loss: 0.2830
# Iteration: 9945; Percent complete: 99.5%; Average loss: 0.2560
# Iteration: 9946; Percent complete: 99.5%; Average loss: 0.2660
# Iteration: 9947; Percent complete: 99.5%; Average loss: 0.2611
# Iteration: 9948; Percent complete: 99.5%; Average loss: 0.2663
# Iteration: 9949; Percent complete: 99.5%; Average loss: 0.2818
# Iteration: 9950; Percent complete: 99.5%; Average loss: 0.3155
# Iteration: 9951; Percent complete: 99.5%; Average loss: 0.2680
# Iteration: 9952; Percent complete: 99.5%; Average loss: 0.3369
# Iteration: 9953; Percent complete: 99.5%; Average loss: 0.2896
# Iteration: 9954; Percent complete: 99.5%; Average loss: 0.4039
# Iteration: 9955; Percent complete: 99.6%; Average loss: 0.2885
# Iteration: 9956; Percent complete: 99.6%; Average loss: 0.3088
# Iteration: 9957; Percent complete: 99.6%; Average loss: 0.3429
# Iteration: 9958; Percent complete: 99.6%; Average loss: 0.2953
# Iteration: 9959; Percent complete: 99.6%; Average loss: 0.3031
# Iteration: 9960; Percent complete: 99.6%; Average loss: 0.2541
# Iteration: 9961; Percent complete: 99.6%; Average loss: 0.2849
# Iteration: 9962; Percent complete: 99.6%; Average loss: 0.3307
# Iteration: 9963; Percent complete: 99.6%; Average loss: 0.2822
# Iteration: 9964; Percent complete: 99.6%; Average loss: 0.2673
# Iteration: 9965; Percent complete: 99.7%; Average loss: 0.3717
# Iteration: 9966; Percent complete: 99.7%; Average loss: 0.2863
# Iteration: 9967; Percent complete: 99.7%; Average loss: 0.2886
# Iteration: 9968; Percent complete: 99.7%; Average loss: 0.2783
# Iteration: 9969; Percent complete: 99.7%; Average loss: 0.2147
# Iteration: 9970; Percent complete: 99.7%; Average loss: 0.2895
# Iteration: 9971; Percent complete: 99.7%; Average loss: 0.2763
# Iteration: 9972; Percent complete: 99.7%; Average loss: 0.3318
# Iteration: 9973; Percent complete: 99.7%; Average loss: 0.2729
# Iteration: 9974; Percent complete: 99.7%; Average loss: 0.2956
# Iteration: 9975; Percent complete: 99.8%; Average loss: 0.3648
# Iteration: 9976; Percent complete: 99.8%; Average loss: 0.2746
# Iteration: 9977; Percent complete: 99.8%; Average loss: 0.2641
# Iteration: 9978; Percent complete: 99.8%; Average loss: 0.2965
# Iteration: 9979; Percent complete: 99.8%; Average loss: 0.2876
# Iteration: 9980; Percent complete: 99.8%; Average loss: 0.3132
# Iteration: 9981; Percent complete: 99.8%; Average loss: 0.3082
# Iteration: 9982; Percent complete: 99.8%; Average loss: 0.3143
# Iteration: 9983; Percent complete: 99.8%; Average loss: 0.2270
# Iteration: 9984; Percent complete: 99.8%; Average loss: 0.2935
# Iteration: 9985; Percent complete: 99.9%; Average loss: 0.2782
# Iteration: 9986; Percent complete: 99.9%; Average loss: 0.3042
# Iteration: 9987; Percent complete: 99.9%; Average loss: 0.2661
# Iteration: 9988; Percent complete: 99.9%; Average loss: 0.3002
# Iteration: 9989; Percent complete: 99.9%; Average loss: 0.3097
# Iteration: 9990; Percent complete: 99.9%; Average loss: 0.2897
# Iteration: 9991; Percent complete: 99.9%; Average loss: 0.2574
# Iteration: 9992; Percent complete: 99.9%; Average loss: 0.3527
# Iteration: 9993; Percent complete: 99.9%; Average loss: 0.3172
# Iteration: 9994; Percent complete: 99.9%; Average loss: 0.2948
# Iteration: 9995; Percent complete: 100.0%; Average loss: 0.3293
# Iteration: 9996; Percent complete: 100.0%; Average loss: 0.2416
# Iteration: 9997; Percent complete: 100.0%; Average loss: 0.2589
# Iteration: 9998; Percent complete: 100.0%; Average loss: 0.3256
# Iteration: 9999; Percent complete: 100.0%; Average loss: 0.2158
# Iteration: 10000; Percent complete: 100.0%; Average loss: 0.2949
# Model saved to /content/drive/My Drive/Movie_Corpus/AAI_520_V3.pth

# %%
#Set dropout layers to evaluation mode
encoder.eval()
decoder.eval()
#Initialize the searcher
searcher = GreedySearchDecoder(encoder, decoder)
#Chat
evaluateInput(encoder, decoder, searcher, vocab)
# Out:
# > Hello!
# Bot: i must speak with you miss flaemm .
# > What is wrong?
# Bot: i don t know . nothing . everything
# > What happened?
# Bot: i didn t have the guts for it .
# > Did you do it?
# Bot: i think so . the press .
# > Did you press the button? It is urgent
# Bot: the hell ? ? ?
# > I told you to press it!
# Bot: what was the other side ? him ?
# > Yes, James was on the other side
# Bot: no . it out . valentine .
# > Valentine is dead
# Bot: no it s not . is penelope .
# > Penelope died with Valentine
# Bot: i know . . murder
# > Which is why I said to press the button
# Bot: the day after tomorrow . the money .
# > Forget the money. Did you press it?
# Bot: i m sorry . . . .
# > What does that mean?
# Bot: it means . . . s discount .
# > Is that a no?
# Bot: yes . i thought so . a is .
# > I cannot believe you
# Bot: why not ? ?
# > Because I think you are lying for Valentine
# Bot: right . i ll be right back . everything
# > quit

# %% [markdown]
#  - After training, we can chat with out chatbot! Enter "q" or "quit" to quit interactions.

# %% [markdown]
# #Model Evaluations
#
#  - Evaluating a chatbot had proven to be a bit tricky. Given the someone unexpected output of terms for every input, using a direct accuracy measure would prove fruitless. Semantic similarity was considered, but it's computational complexity proved difficult to implement. Instead, we proceed with 3 different metrics:
#
#   - Perplexity (Measure of how well our model predicts a sample)
#      - A lower value is better, with 10-40 being the standard of a reasonable model. Above 100, the model struggles to calculate predictions for words.
#
#   - BLEU Score (Evaluates quality of generated response against our data)
#       - Conversely, a high BLEU score (close to 1) shows a high overlap between the model's generated response from conversation and the referenced response (our defined pairs from the dataset). Scores below 0.3 will often show a struggling model.
#
#   - ROUGE Score (Measures recall of our language model).
#       - For rouge-1 and rouge-l, a score around 0.3-0.5 is solid, with rouge-2 scores of 0.2 being sufficient, with increases to 1 indicating increased excellence.
#
#  - With these three measurements, we can capture a rough quantitative idea of how well our model performs.

# %%
rouge = Rouge()

# %% [markdown]
#  - Function to calculate Rouge score

# %%
def RougeScore(reference, candidate):
    scores = rouge.get_scores(candidate, reference)
    return scores

# %% [markdown]
#  - Function to calculate BLEU score

# %%
def bleu(reference, candidate):
    reference_tokens = [reference.split()]
    candidate_tokens = candidate.split()
    score = sentence_bleu(reference_tokens, candidate_tokens)
    return score

# %% [markdown]
#  - Function to calculate perplexity

# %%
def perplexity(loss):
    return math.exp(loss)

# %% [markdown]
#  - Function to evaluate loss after training

# %%
def evaluate_w_loss(encoder, decoder, searcher, vocab, input_sentence, target_sentence):
    #Generate response
    generated_response = evaluate(encoder, decoder, searcher, vocab, input_sentence)
    generated_sentence = ' '.join([word for word in generated_response if word not in ['EOS', 'PAD']])
    loss = 0.2949
    return generated_sentence, loss

# %% [markdown]
#  - We will use the first 3000 input/output pairs we created earlier in the project as a sizable and solid reference dataset.

# %%
#Load the first 10 pairs to use for evaluation
test_pairs = pairs[:3000]

#Initialize everything
total_bleu = 0
total_rouge = []
total_loss = 0

# %% [markdown]
#   - Function to show and visualize calculations.

# %%
for input_sentence, reference_sentence in test_pairs:
    #Model sentence returned
    generated_sentence, loss = evaluate_w_loss(encoder, decoder, searcher, vocab, input_sentence, reference_sentence)
    #Bleu score first
    bleu_score = bleu(reference_sentence, generated_sentence)
    total_bleu += bleu_score
    #Rouge Score
    rouge_scores = RougeScore(reference_sentence, generated_sentence)
    total_rouge.append(rouge_scores)
    #Loss for Perplexity
    total_loss += loss

# %% [markdown]
#  - Final BLEU Score

# %%
#Now average BLEU score
average_bleu = total_bleu / len(test_pairs)
print(f"\nAverage BLEU Score: {average_bleu}")
# Out:
# Average BLEU Score: 0.38717152670633176

# %% [markdown]
#  - Final Rouge score

# %%
#Rouge score
average_rouge = {'rouge-1': {'f': 0, 'p': 0, 'r': 0}, 'rouge-2': {'f': 0, 'p': 0, 'r': 0}, 'rouge-l': {'f': 0, 'p': 0, 'r': 0}}
for score in total_rouge:
    for key in score[0]:
        for metric in score[0][key]:
            average_rouge[key][metric] += score[0][key][metric] / len(test_pairs)
print(f"Average ROUGE Score: {average_rouge}")
# Out:
# Average ROUGE Score: {'rouge-1': {'f': 0.6664905029492556, 'p': 0.6091484126984121, 'r': 0.7848664021163826}, 'rouge-2': {'f': 0.53859362385242, 'p': 0.47086732804232795, 'r': 0.6875218253968162}, 'rouge-l': {'f': 0.6662485476823004, 'p': 0.6089222222222217, 'r': 0.7845932539682345}}

# %% [markdown]
#  - Final Perplexity Value

# %%
#Perplexity
average_loss = total_loss / len(test_pairs)
perplexity_val = perplexity(average_loss)
print(f"Perplexity: {perplexity_val}")
# Out:
# Perplexity: 1.3429920527658032

# %% [markdown]
# #Results

# %% [markdown]
#  - Average BLEU Score: 0.387
#
#  - Average Rouge 1 Score: 0.686
#
#  - Average Rouge 2 Score: 0.565
#
#  - Average Rouge L Score: 0.687
#
#  - Perplexity: 1.343

# %% [markdown]
# ##Bleu Score

# %% [markdown]
#  - The values lend a quantitative understanding to what is an otherwise abstract objective - chatting with a language model. The BLEU score is an interesting metric that revolves around how close our predicted sentence generated by the model is to a human-generated target sentence (for which our dataset is composed). Scores range between 0 and 1, with 0.6 or 0.7 often being the achievements of large language models like ChatGPT-2. The idea is to capture a value that encompasses n-grams, or a set of 'n' consecutive terms in a sentence, and the precision of the terms (if the same words are used in the target sentence as the generated sentence with some nuance considerations). Once the values are computed across 1-4 n-grams, a uniform weighted output (BLEU Score) is generated. In our particular model, the score of 0.387 is not outstanding but impressive considering our model and dataset. The value itself may be boosted by the vocabulary of our model originating exclusively from the dataset and therefore boosting the precision calculation, but a 0.387 remains an impressive score. Some area's where it may be falling short can be the generated sentence structure and order, for which the higher 'n' values of n-gram calculations may be affected.

# %% [markdown]
# ## Rouge-1 & 2 Score

# %% [markdown]
#  - The Rouge 1/2 Score: The rouge-1 score and rouge-2 score are relatively simple, with the only difference being the n-gram values by which they compute precision. Our rouge-1 score comes out to 0.686 with rouge-2 being 0.565, indicating that our model generated an output with vocabulary overlapping the expected outcome from our Movie Corpus 68.6% of the time on a 1 instance basis, and 56.6% of the time on a 2 instance basis. With increased 'n' values, the rouge score does decrease despite the vocabulary of our model originating exclusively from the Movie Corpus dataset, showing the limitations of our model in sentence generation.

# %% [markdown]
# ##Rouge L Score:

# %% [markdown]
#  - The Rouge L score is based on the longest common subsequence between our model and the sentence pairs we created as a reference. The average rouge-l score of 68.7% is almost exactly the same as our rouge-1 score, showing that the longest sequence of similarity tends to overlap only on 1-gram values, again showing the limitations of our model. Realistically a longer shared sequence would also reflect in the chatbot's responses and a score more similar to rouge-2 scores.

# %% [markdown]
# ## Perplexity

# %% [markdown]
#  - Perplexity goes off the idea of how a language model operates, in that all generations of words and sentences are just probabilitiy distributions of choosing a term from the vocabulary the model can use. In our model, we use Greedy Search to simply choose the highest probability term for each sequence in a sentence. Perplexity is the measure of "surprise" for our model, in that it shows how surprised the model is to see new data. Ideally, a lower perplexity, the better the model. Since we are comparing our model's input against 3,000 sentence pairs from which the model itself was trained, a perplexity value of 1.343 is expectedly good (it recognizes the data on which it was trained on). In a way, although not a great measure of our model on user input, it demonstrates that our chatbot did train well on the dataset and is able to recognize a randomized subset of instances from the dataset. It reinforces the idea that our chatbot is well-trained on the dataset and performing well all things considered.
